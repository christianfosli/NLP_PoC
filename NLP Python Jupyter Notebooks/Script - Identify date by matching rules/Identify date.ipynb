# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (2.3.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.8.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (7.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.19.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (4.54.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: setuptools in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (49.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)

# %%
import spacy
print(spacy.__version__)
# Out:
# 2.3.5

# %%
# Had to run this to make something below work.
# This is a donwgrade of numpy to a version without a bug.
# This is a temp solution until a new version of numpy has solved the bug.
# !pip install numpy==1.19.3 --user
# Out:
# [autoreload of numpy._globals failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'numpy' not in sys.modules
# ]
# [autoreload of numpy.__config__ failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'numpy' not in sys.modules
# ]
# [autoreload of numpy.version failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'numpy' not in sys.modules
# ]
# [autoreload of numpy._distributor_init failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'numpy' not in sys.modules
# ]
# [autoreload of numpy.compat failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'numpy' not in sys.modules
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 790, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\matrixlib\__init__.py", line 6, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 790, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\__init__.py", line 45, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "C:\Users\lhustvei\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "C:\Users\lhustvei\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\ma\core.py", line 6535, in __setattr__
#     return super(MaskedConstant, self).__setattr__(attr, value)
# TypeError: super(type, obj): obj must be an instance or subtype of type
# ]
# Requirement already satisfied: numpy==1.19.3 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (1.19.3)

# %%
forward_lines_as_spacy_ner_format = [{'text': '3. Fire, machinery and electric installations\n',
  'ents': [],
  'title': 0},
 {'text': '\n', 'ents': [], 'title': 1},
 {'text': 'Section 7. Scope of application of this chapter\n',
  'ents': [],
  'title': 2},
 {'text': '(1) This chapter applies to vessels constructed after 2 January 1988.\n',
  'ents': [],
  'title': 3},
 {'text': '(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter.\n',
  'ents': [],
  'title': 4},
 {'text': '(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new vessel.\n',
  'ents': [],
  'title': 5},
 {'text': '\n', 'ents': [], 'title': 6},
 {'text': '0\tAmended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).\n',
  'ents': [],
  'title': 7},
 {'text': '\n', 'ents': [], 'title': 8},
 {'text': '\n', 'ents': [], 'title': 9},
 {'text': '\n', 'ents': [], 'title': 10},
 {'text': 'Section 8. Fire safety\n', 'ents': [], 'title': 11},
 {'text': '(1) Vessels constructed after 1 January 1992 shall have structural fire protection in accordance with chapter C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.\n',
  'ents': [],
  'title': 12},
 {'text': '(2) Vessels constructed before 1 January 1992 shall have structural fire protection in accordance with the rules applicable at the time of construction of the vessel.\n',
  'ents': [],
  'title': 13},
 {'text': '(3) Irrespective of the year of construction of the vessel, gasfired installations shall satisfy the requirements of Regulations of 20 October 1983 No. 1580 on safety precautions for gasfired installations, etc. operating on propane or other liquefied hydrocarbon gases used on board vessels.\n',
  'ents': [],
  'title': 14},
 {'text': '\n', 'ents': [], 'title': 15},
 {'text': 'Section 9. Oil-fired stoves\n', 'ents': [], 'title': 16},
 {'text': '(1) Stoves with electric power supply shall have an oil supply which shuts off automatically if:\n',
  'ents': [],
  'title': 17},
 {'text': 'a)\tthe stove is over-heated (maximum 400°C in smoke gas);\n',
  'ents': [],
  'title': 18},
 {'text': '\n', 'ents': [], 'title': 19},
 {'text': 'b)\tthe flame goes out;\n', 'ents': [], 'title': 20},
 {'text': '\n', 'ents': [], 'title': 21},
 {'text': 'c)\ta failure occurs in the supply of air or power.\n',
  'ents': [],
  'title': 22},
 {'text': '\n', 'ents': [], 'title': 23},
 {'text': '(2) Stoves without electric power supply shall have an oil supply which shuts off automatically if\n',
  'ents': [],
  'title': 24},
 {'text': 'a)\tthe stove is over-heated (maximum 400°C in smoke gas);\n',
  'ents': [],
  'title': 25},
 {'text': '\n', 'ents': [], 'title': 26},
 {'text': 'b)\tthe flame goes out.\n', 'ents': [], 'title': 27},
 {'text': '\n', 'ents': [], 'title': 28},
 {'text': '(3) Drip regulation stoves (regulation valve with observation hole) need not have automatic shutoff of the oil supply if the flame will go out due to the oil consumption being limited by an oil regulation valve. The installation instructions shall indicate the maximum permitted difference in height between the oil tank and the regulation valve. An oil pressure reduction valve shall be fitted if satisfactory regulation of the oil supply cannot be achieved through pressure variations. The overflow system shall be capable of receiving the full volume of the tank.\n',
  'ents': [],
  'title': 29},
 {'text': '(4) The resetting of the safety function shall be manual.\n',
  'ents': [],
  'title': 30},
 {'text': '(5) The installation instructions shall be kept on board. The instructions for use shall be posted near the stove.\n',
  'ents': [],
  'title': 31},
 {'text': '(6) Stoves with accessories shall be installed in accordance with the installation instructions from the manufacturer.\n',
  'ents': [],
  'title': 32},
 {'text': '(7) Stoves shall have smoke outlet to uptake.\n',
  'ents': [],
  'title': 33},
 {'text': '\n', 'ents': [], 'title': 34},
 {'text': 'Section 10. Installation, etc. of oilfired stove\n',
  'ents': [],
  'title': 35},
 {'text': '(1) Stoves shall be securely fixed to the floor or to a fixed bench, if possible near the centre line of the vessel.\n',
  'ents': [],
  'title': 36},
 {'text': '(2) Stoves without automatic shutoff of oil supply in the event of the flame going out, shall be provided with a separate oil tank of maximum 40 litres. The oil tank shall not be filled automatically, and shall be placed on the height indicated in the installation instructions.\n',
  'ents': [],
  'title': 37},
 {'text': '(3) The oil tank shall have a water separator and a plug for draining off possible collection of water and shall be placed outside the space where the stove is installed.\n',
  'ents': [],
  'title': 38},
 {'text': '(4) The oil pipe to the regulator shall have a filter for the separation of mud and water. The filter shall not be fitted above the stove.\n',
  'ents': [],
  'title': 39},
 {'text': '(5) Pipes made of copper or equivalent material shall be used between the tank and the stove. The pipes shall be fixed and placed so as to prevent the formation of air pockets.\n',
  'ents': [],
  'title': 40},
 {'text': '(6) Stoves shall have overflow openings with drain pipes and collection tank. Both the stove and the float valve, if used, shall be connected to the collection tank.\n',
  'ents': [],
  'title': 41},
 {'text': '(7) Smoke uptake pipes shall have a diameter which is not less than the smoke outlet of the stove, and the piping shall be made as straight as possible.\n',
  'ents': [],
  'title': 42},
 {'text': '(8) Drainage of condensed water/mud, cleaning of filters, inspection of burners and other components shall be carried out in the time intervals stipulated in the operating instructions.\n',
  'ents': [],
  'title': 43},
 {'text': '(9) Spaces with a stove shall be well ventilated.\n',
  'ents': [],
  'title': 44},
 {'text': '(10) On vessels of 8 to 15 metres in overall length the stove shall be inspected by an approved company within six months of being installed.\n',
  'ents': [],
  'title': 45},
 {'text': '\n', 'ents': [], 'title': 46},
 {'text': 'Section 11. Insulation of fireplaces, etc.\n',
  'ents': [],
  'title': 47},
 {'text': '(1) Bulkheads shall be insulated with non-combustible material in accordance with Appendix 4.\n',
  'ents': [],
  'title': 48},
 {'text': '(2) Below stoves, wooden floor or combustible floor covering shall be protected by steel or aluminium sheets covering the whole floor area under the fireplace and in front of the stove at least 15 cm from the fire door. Where the stove is placed on a bench or similar, the bench shall be protected by non-combustible material.\n',
  'ents': [],
  'title': 49},
 {'text': '\n', 'ents': [], 'title': 50},
 {'text': 'Section 12. Smoke uptake and exhaust pipes\n',
  'ents': [],
  'title': 51},
 {'text': '(1) Smoke uptakes and exhaust pipes shall consist of at least 3 mm thick steel plates and shall be securely fixed. Smoke uptakes shall be carried at least 1.3 m above deck.\n',
  'ents': [],
  'title': 52},
 {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n',
  'ents': [],
  'title': 53},
 {'text': '(3) When smoke uptake is carried along a bulkhead, the bulkhead shall be insulated with non-combustible material. Smoke uptakes shall not be placed closer than 10 cm to insulated bulkheads. Where the smoke uptake (pipe) is insulated with saucer formed rockwool or mineral wool twine of at least 2 cm thickness, the distance to the insulated bulkhead may be reduced to 5 cm.\n',
  'ents': [],
  'title': 54},
 {'text': '(4) Any exhaust manifold which is not watercooled, and parts of exhaust pipes which may cause ignition, shall be insulated so that oil cannot penetrate. Where gases are watercooled, other arrangements may be accepted. Exhaust pipes shall not be closer than 2 cm to combustible material.\n',
  'ents': [],
  'title': 55},
 {'text': '(5) Oil pipes shall be placed as far as possible away from exhaust pipes and hot engine parts.\n',
  'ents': [],
  'title': 56},
 {'text': '\n', 'ents': [], 'title': 57},
 {'text': 'Section 13. Insulation with non-combustible material\n',
  'ents': [],
  'title': 58},
 {'text': 'Non-combustible material means a material which, when tested and evaluated in accordance with MSC.61(67) (the FTP Code), satisfies the requirements for qualifying materials as non-combustible. The insulation shall, if necessary in order to preserve the fire-insulating effect, be mounted with a sheet of galvanized steel or aluminium.\n',
  'ents': [],
  'title': 59},
 {'text': '\n', 'ents': [], 'title': 60},
 {'text': 'Section 14. Insulation of machinery spaces in wooden vessels\n',
  'ents': [],
  'title': 61},
 {'text': '(1) Machinery spaces in wooden vessels shall have floors of steel or aluminium plates. Machinery spaces shall be insulated with non-combustible material or have an approved fire-extinguishing system.\n',
  'ents': [],
  'title': 62},
 {'text': '(2) In machinery spaces without inside planking, wooden casings, beams and surfaces under deck as well as bulkheads forwards and aft in the machinery space shall be insulated with non-combustible material.\n',
  'ents': [],
  'title': 63},
 {'text': '(3) In machinery spaces with inside planking, all woodwork shall be insulated with non-combustible material down to the lower edge of the floor. No insulation is required behind fuel oil tanks if the other insulation is fitted tightly around the tank.\n',
  'ents': [],
  'title': 64},
 {'text': '(4) In vessels where the engine is not placed in a separate compartment, all combustible material which is exposed to heat from exhaust manifolds, exhaust pipes, etc. shall be insulated with non-combustible material. When an engine cover is used, this shall be insulated on the inside and be mounted with a galvanized steel or aluminium sheet.\n',
  'ents': [],
  'title': 65},
 {'text': '\n', 'ents': [], 'title': 66},
 {'text': 'Section 15. Fire-extinguishing systems in machinery spaces\n',
  'ents': [],
  'title': 67},
 {'text': '(1) Vessels of 10.67 to 15 metres in overall length shall have a fire-extinguishing system. When there are persons on board, the fire-extinguishing system shall only be capable of manual release.\n',
  'ents': [],
  'title': 68},
 {'text': '(2) Extinguishing medium shall be of an approved type. The amount of extinguishing medium is determined in each individual case depending on the size of the machinery space.\n',
  'ents': [],
  'title': 69},
 {'text': '(3) The fire-extinguishing system shall only be capable of being released from a position outside the machinery space. The release equipment shall be clearly marked, provided with instructions for use and protected against unintentional release.\n',
  'ents': [],
  'title': 70},
 {'text': '(4) Vessels of less than 10.67 metres in overall length constructed after 1 January 1992 may as an alternative be equipped with a fire-extinguishing system in accordance with guidelines laid down in chapter C14 of Nordic Boat Standard (1990).\n',
  'ents': [],
  'title': 71},
 {'text': '(5) CO2 containers and other containers for extinguishing gas which could may be hazardous in the event of a leak, with appurtenant release device, shall be placed in a separate space/locker outside the machinery space. Gastight bulkheads shall be provided to adjacent spaces and entrance from open deck. An alarm signal shall be activated automatically when the CO2 space/locker is opened. It should be ensured that no persons are present in the machinery space before the CO2 gas is released. The space/locker for release of CO2 shall have ventilation to the open air.\n',
  'ents': [],
  'title': 72},
 {'text': '\n', 'ents': [], 'title': 73},
 {'text': 'Section 16. Fire detection and alarm system\n',
  'ents': [],
  'title': 74},
 {'text': '(1) Vessels of 10.67 to 15 metres in overall length, irrespective of year of construction, shall have fire detection system and fire alarm system for machinery spaces and smoke alarm system for the cabins in accordance with Appendix 5.\n',
  'ents': [],
  'title': 75},
 {'text': '(2) Vessels of less than 10.67 meters in overall length shall be fitted with at least one smoke detector and one heat detector in machinery spaces, at least one smoke detector in recreational spaces, and at least one smoke detector in the wheelhouse.\n',
  'ents': [],
  'title': 76},
 {'text': '\n', 'ents': [], 'title': 77},
 {'text': 'Section 17. Fire extinguishers\n', 'ents': [], 'title': 78},
 {'text': '(1) All vessels, irrespective of year of construction, shall have at least two approved fire extinguishers of at least 6 kg. At least one approved fire extinguisher shall be placed at a suitable place outside the machinery space and at least one approved fire extinguisher shall be placed in the accommodation spaces. For vessels without wheelhouse or accommodation spaces one fire extinguisher is sufficient.\n',
  'ents': [],
  'title': 79},
 {'text': '(1) Fire extinguishers with pressurised extinguishing medium shall not be placed in accommodation spaces. Fire extinguishers which may be exposed to frost shall be of a frost-proof type.\n',
  'ents': [],
  'title': 80},
 {'text': '(3) At least one spare charge shall be provided for each extinguisher. If the extinguisher is of a type that cannot be charged on board, the number of extinguishers shall be increased by 50 per cent.\n',
  'ents': [],
  'title': 81},
 {'text': '(4) Fire extinguishers shall be inspected annually in accordance with NS3910. The date of the inspection shall be marked on the extinguisher.\n',
  'ents': [],
  'title': 82},
 {'text': '\n', 'ents': [], 'title': 83},
 {'text': '0\tAmended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).\n',
  'ents': [],
  'title': 84},
 {'text': '\n', 'ents': [], 'title': 85},
 {'text': '\n', 'ents': [], 'title': 86},
 {'text': '\n', 'ents': [], 'title': 87},
 {'text': 'Section 18. Ventilation systems\n', 'ents': [], 'title': 88},
 {'text': "The vessel's machinery space shall have at least two ventilators capable of being closed from deck. Cabins shall have at least two ventilators with a diameter of at least 8 cm.\n",
  'ents': [],
  'title': 89},
 {'text': '\n', 'ents': [], 'title': 90},
 {'text': 'Section 19. Materials, etc.\n', 'ents': [], 'title': 91},
 {'text': 'Materials, varnishes, paints, etc. produced on a nitrocellulose basis or any other basis which will readily ignite are not permitted to be used anywhere on board.\n',
  'ents': [],
  'title': 92},
 {'text': '\n', 'ents': [], 'title': 93},
 {'text': 'Section 20. Storage of oil fuel and other flammable liquids\n',
  'ents': [],
  'title': 94},
 {'text': '(1) Oil fuel shall be stored in tanks of steel or equivalent material.\n',
  'ents': [],
  'title': 95},
 {'text': '(2) Outlets from oil fuel tanks shall be fitted with a closing valve or cock on the tank itself, which is capable of being closed from the deck. Test cocks and cocks for oil gauge glass shall be of a self-closing type. The tank shall be fitted with drip trays. In decked vessels with machinery space, filling pipes and airing pipes shall be carried through the deck and into open air.\n',
  'ents': [],
  'title': 96},
 {'text': '(3) If extra fuel or other flammable liquids cannot be placed on open deck, they shall be stored in suitable containers in a well-ventilated room/locker with a door communicating only with open deck and without electrical or other sources of ignition.\n',
  'ents': [],
  'title': 97},
 {'text': '\n', 'ents': [], 'title': 98},
 {'text': 'Section 21. Materials in pipelines, etc.\n',
  'ents': [],
  'title': 99},
 {'text': '(1) Seawater pipes, bilge pipes, pipes conveying oil and other pipelines required for the safety of the ship shall be made of non-combustible material. Short, flexible pipe connections made of a material which is not easily rendered ineffective by heat, may be accepted on:\n',
  'ents': [],
  'title': 100},
 {'text': 'a)\tseawater pipes;\n', 'ents': [], 'title': 101},
 {'text': '\n', 'ents': [], 'title': 102},
 {'text': 'b)\tshort, flexible pipe connections on pipes conveying oil, when necessitated by vibrations.\n',
  'ents': [],
  'title': 103},
 {'text': '\n', 'ents': [], 'title': 104},
 {'text': '(2) Where failure of the material due to fire may lead to flooding, scuppers, sanitary discharges or other outlets which are close to the waterline shall be made of oil-resistant and reinforced materials which are not easily damaged by heat.\n',
  'ents': [],
  'title': 105},
 {'text': '\n', 'ents': [], 'title': 106},
 {'text': 'Section 22.  Machinery and piping systems\n',
  'ents': [],
  'title': 107},
 {'text': '(1) Vessels constructed after 1 January 1992 shall satisfy the requirements of Nordic Boat Standard (1990)\n',
  'ents': [],
  'title': 108},
 {'text': 'a)\tC6 on bilge systems;\n', 'ents': [], 'title': 109},
 {'text': '\n', 'ents': [], 'title': 110},
 {'text': 'b)\tC9 on oil fuel systems;\n', 'ents': [], 'title': 111},
 {'text': '\n', 'ents': [], 'title': 112},
 {'text': 'c)\tC8 on engine installations; and\n', 'ents': [], 'title': 113},
 {'text': '\n', 'ents': [], 'title': 114},
 {'text': 'd)\tC7 and C10 on rudder and propeller arrangements.\n',
  'ents': [],
  'title': 115},
 {'text': '\n', 'ents': [], 'title': 116},
 {'text': '(2) Vessels constructed before 1 January 1992 shall as far as possible satisfy the requirements of Nordic Boat Standard (1990 chapter C6 on bilge systems.\n',
  'ents': [],
  'title': 117},
 {'text': '\n', 'ents': [], 'title': 118},
 {'text': 'Section 23. Electrical installations\n', 'ents': [], 'title': 119},
 {'text': '(1) Vessels of 6 to 15 metres in overall length constructed after 1 January 1992 with electrical installations with voltages of up to 50 V shall satisfy the requirements of Nordic Boat Standard (1990) C11 on electrical installations.\n',
  'ents': [],
  'title': 120},
 {'text': '(2) Vessels of 6 to 15 metres in overall length constructed before 1 January 1992 with electrical installations with voltages of up to 50 V shall be in compliance with the rules in force at the time of construction.\n',
  'ents': [],
  'title': 121},
 {'text': '(3) Vessels of 6 to 15 metres in overall length constructed between 1 January 1992 and 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in the now repealed Regulations of 1 March 1990 No. 125 for electrical installations - Maritime installations.\n',
  'ents': [],
  'title': 122},
 {'text': '(4) Vessels of 6 to 15 metres in overall length constructed after 1 January 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in Regulations of 4 December 2001 No. 1450 concerning maritime electrical installations, laid down by the Norwegian Directorate for Civil Protection.\n',
  'ents': [],
  'title': 123},
 {'text': '\n', 'ents': [], 'title': 124},
 {'text': 'Section 24. Emergency source of power and emergency lighting, etc.\n',
  'ents': [],
  'title': 125},
 {'text': '(1) Vessels of 10.67 to 15 metres in overall length constructed after 1 January 1992 shall have an emergency source of power providing satisfactory lighting for at least 2 hours to:\n',
  'ents': [],
  'title': 126},
 {'text': 'a)\tlighting in areas with life-saving appliances and launching arrangements;\n',
  'ents': [],
  'title': 127},
 {'text': '\n', 'ents': [], 'title': 128},
 {'text': 'b)\tlighting in alleyways, stairways and exits to the life-saving appliances and of the sea where the life-saving appliances are launched;\n',
  'ents': [],
  'title': 129},
 {'text': '\n', 'ents': [], 'title': 130},
 {'text': 'c)\tnecessary navigation lights; and\n', 'ents': [], 'title': 131},
 {'text': '\n', 'ents': [], 'title': 132},
 {'text': 'd)\trequired alarm system.\n', 'ents': [], 'title': 133},
 {'text': '\n', 'ents': [], 'title': 134},
 {'text': '(2) The emergency power shall be provided by one of the following two sources:\n',
  'ents': [],
  'title': 135},
 {'text': 'a)\tan accumulator battery capable of carrying the load pursuant to the first paragraph without recharging or suffering an excessive voltage drop, and which is automatically connected to the emergency switchboard when the main power fails; or\n',
  'ents': [],
  'title': 136},
 {'text': '\n', 'ents': [], 'title': 137},
 {'text': 'b)\ta generator driven by a suitable type of power machinery with an independent supply of fuel, appropriate starting arrangements and driven by fuel having a flashpoint of not less than 43°C (110°F).\n',
  'ents': [],
  'title': 138},
 {'text': '\n', 'ents': [], 'title': 139},
 {'text': '(3) The entire installation shall be capable of operating even when the vessel is listed to 22.5 degrees or when the trim of the vessel is 10 degrees.\n',
  'ents': [],
  'title': 140},
 {'text': '(4) Switchboards for main power and emergency power shall be clearly marked and be placed, as far as practicable, so that they cannot be exposed to water or fire. The emergency source of power shall if possible be placed above deck. If the emergency source of power is placed in the machinery space, it shall be placed above the floor and in a well-ventilated place.\n',
  'ents': [],
  'title': 141},
 {'text': '(5) The emergency source of power and the emergency lighting on vessels constructed before 1 January 1992 shall be in accordance with the rules in force at the time of construction.\n',
  'ents': [],
  'title': 142},
 {'text': '\n', 'ents': [], 'title': 143},
 {'text': 'Section 25. Equivalents\n', 'ents': [], 'title': 144},
 {'text': 'Vessels constructed pursuant to Nordic Boat Standard (1990) are considered to satisfy the requirements of sections 18, 19 and 20.\n',
  'ents': [],
  'title': 145}]

# %%
import spacy
from spacy.lang.en import English
from spacy.matcher import Matcher

nlp = English()

doc = nlp("(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter. (1) Vessels constructed after 1 January 1992 shall satisfy the requirements of Nordic Boat Standard (1990)")

matcher = Matcher(nlp.vocab)

date_pattern = [{'IS_DIGIT': True},
{"LOWER": {"IN": ["january","february","march","april","may","june","july","august","september","october","november","december"]}},
{'IS_DIGIT': True, 'LENGTH': 4}]

matcher.add("DATE", None, date_pattern)

result = []

for match_id, token_start, token_end in matcher(doc):

    # convert token_span to char_span.
    # char_span is needed to display correctly withdisplacy.render().
    span = doc[token_start:token_end]
    span_char_start = span[0].idx
    span_char_end = span[-1].idx + len(span[-1].text)

    match_id_as_string = nlp.vocab.strings[match_id]

    identified_entity = {'start': span_char_start, 'end': span_char_end, 'label': match_id_as_string}
    result.append(identified_entity)

result
# Out:
# [{'start': 31, 'end': 45, 'label': 'DATE'},
#  {'start': 265, 'end': 279, 'label': 'DATE'}]

# %% [markdown]
# # Functions run from .py file

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import identify_date

from identify_date import identify_date_in_text

importlib.reload(identify_date)

################
################

#identify_date_in_text("(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter. (1) Vessels constructed after 1 January 1992 shall satisfy the requirements of Nordic Boat Standard (1990)")

identify_date_in_text("(1) This chapter applies to vessels constructed after 2 January 1988.\n")
# Out:
# [{'start': 54, 'end': 68, 'label': 'DATE'}]

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import identify_date

from identify_date import identify_date_in_text

importlib.reload(identify_date)

################
################

for line in forward_lines_as_spacy_ner_format:

    text = line['text']

    if text != "\n":
        result_in_a_list = identify_date_in_text(text)

        if result_in_a_list:
            print(result_in_a_list)
# Out:
# [{'start': 54, 'end': 68, 'label': 'DATE'}]
# [{'start': 31, 'end': 45, 'label': 'DATE'}]
# [{'start': 27, 'end': 37, 'label': 'DATE'}, {'start': 60, 'end': 70, 'label': 'DATE'}]
# [{'start': 30, 'end': 44, 'label': 'DATE'}]
# [{'start': 31, 'end': 45, 'label': 'DATE'}]
# [{'start': 132, 'end': 147, 'label': 'DATE'}]
# [{'start': 74, 'end': 88, 'label': 'DATE'}]
# [{'start': 27, 'end': 37, 'label': 'DATE'}, {'start': 60, 'end': 70, 'label': 'DATE'}]
# [{'start': 30, 'end': 44, 'label': 'DATE'}]
# [{'start': 31, 'end': 45, 'label': 'DATE'}]
# [{'start': 66, 'end': 80, 'label': 'DATE'}]
# [{'start': 67, 'end': 81, 'label': 'DATE'}]
# [{'start': 68, 'end': 82, 'label': 'DATE'}, {'start': 230, 'end': 242, 'label': 'DATE'}]
# [{'start': 66, 'end': 80, 'label': 'DATE'}, {'start': 202, 'end': 217, 'label': 'DATE'}]
# [{'start': 70, 'end': 84, 'label': 'DATE'}]
# [{'start': 91, 'end': 105, 'label': 'DATE'}]

# %% [markdown]
# # Merge spacy result with spacy ner formated list of text

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import identify_date

from identify_date import merge_spacy_entity_results_to_spacy_ner_format

importlib.reload(identify_date)

################
################

spacy_ner_formated_text_line = {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n',
  'ents': [],
  'title': 53}

spacy_ner_entities_to_be_merged_in_as_a_list = [{'start': 16, 'end': 19, 'label': 'DATE'}, {'start': 6, 'end': 9, 'label': 'DATE'}]

print(merge_spacy_entity_results_to_spacy_ner_format(spacy_ner_formated_text_line,spacy_ner_entities_to_be_merged_in_as_a_list))

spacy_ner_formated_text_line = {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n',
  'ents': [{'start': 16, 'end': 19, 'label': 'DATE'}, {'start': 6, 'end': 9, 'label': 'DATE'}],
  'title': 53}

print("")

print(merge_spacy_entity_results_to_spacy_ner_format(spacy_ner_formated_text_line,spacy_ner_entities_to_be_merged_in_as_a_list))
# Out:
# {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n', 'ents': [{'start': 6, 'end': 9, 'label': 'DATE'}, {'start': 16, 'end': 19, 'label': 'DATE'}], 'title': 53}
#
# {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n', 'ents': [{'start': 6, 'end': 9, 'label': 'DATE'}, {'start': 6, 'end': 9, 'label': 'DATE'}, {'start': 16, 'end': 19, 'label': 'DATE'}, {'start': 16, 'end': 19, 'label': 'DATE'}], 'title': 53}

# %% [markdown]
# # Test the merger function on the data abowe

# %%
result = []

for spacy_line in forward_lines_as_spacy_ner_format:

    print(str(spacy_line['title']))

    if spacy_line['text'] != "\n" and len(spacy_line['text']) > 0:

        identify_date_in_text_result_in_a_list = identify_date_in_text(spacy_line['text'])

        # this result might be empty.

        if identify_date_in_text_result_in_a_list:

            # we have results to merge in.
            # merge in the result using this function.
            new_spacy_line = merge_spacy_entity_results_to_spacy_ner_format(spacy_line,identify_date_in_text_result_in_a_list)

            print(str(spacy_line['title']) + " ok if")
            result.append(new_spacy_line)

        else:
            print(str(spacy_line['title']) + " ok else")
            result.append(spacy_line)
    else:
        print(str(spacy_line['title']) + " ok else")
        result.append(spacy_line)

result
# Out:
# 0
# 0 ok else
# 1
# 1 ok else
# 2
# 2 ok else
# 3
# 3 ok if
# 4
# 4 ok if
# 5
# 5 ok else
# 6
# 6 ok else
# 7
# 7 ok if
# 8
# 8 ok else
# 9
# 9 ok else
# 10
# 10 ok else
# 11
# 11 ok else
# 12
# 12 ok if
# 13
# 13 ok if
# 14
# 14 ok if
# 15
# 15 ok else
# 16
# 16 ok else
# 17
# 17 ok else
# 18
# 18 ok else
# 19
# 19 ok else
# 20
# 20 ok else
# 21
# 21 ok else
# 22
# 22 ok else
# 23
# 23 ok else
# 24
# 24 ok else
# 25
# 25 ok else
# 26
# 26 ok else
# 27
# 27 ok else
# 28
# 28 ok else
# 29
# 29 ok else
# 30
# 30 ok else
# 31
# 31 ok else
# 32
# 32 ok else
# 33
# 33 ok else
# 34
# 34 ok else
# 35
# 35 ok else
# 36
# 36 ok else
# 37
# 37 ok else
# 38
# 38 ok else
# 39
# 39 ok else
# 40
# 40 ok else
# 41
# 41 ok else
# 42
# 42 ok else
# 43
# 43 ok else
# 44
# 44 ok else
# 45
# 45 ok else
# 46
# 46 ok else
# 47
# 47 ok else
# 48
# 48 ok else
# 49
# 49 ok else
# 50
# 50 ok else
# 51
# 51 ok else
# 52
# 52 ok else
# 53
# 53 ok else
# 54
# 54 ok else
# 55
# 55 ok else
# 56
# 56 ok else
# 57
# 57 ok else
# 58
# 58 ok else
# 59
# 59 ok else
# 60
# 60 ok else
# 61
# 61 ok else
# 62
# 62 ok else
# 63
# 63 ok else
# 64
# 64 ok else
# 65
# 65 ok else
# 66
# 66 ok else
# 67
# 67 ok else
# 68
# 68 ok else
# 69
# 69 ok else
# 70
# 70 ok else
# 71
# 71 ok if
# 72
# 72 ok else
# 73
# 73 ok else
# 74
# 74 ok else
# 75
# 75 ok else
# 76
# 76 ok else
# 77
# 77 ok else
# 78
# 78 ok else
# 79
# 79 ok else
# 80
# 80 ok else
# 81
# 81 ok else
# 82
# 82 ok else
# 83
# 83 ok else
# 84
# 84 ok if
# 85
# 85 ok else
# 86
# 86 ok else
# 87
# 87 ok else
# 88
# 88 ok else
# 89
# 89 ok else
# 90
# 90 ok else
# 91
# 91 ok else
# 92
# 92 ok else
# 93
# 93 ok else
# 94
# 94 ok else
# 95
# 95 ok else
# 96
# 96 ok else
# 97
# 97 ok else
# 98
# 98 ok else
# 99
# 99 ok else
# 100
# 100 ok else
# 101
# 101 ok else
# 102
# 102 ok else
# 103
# 103 ok else
# 104
# 104 ok else
# 105
# 105 ok else
# 106
# 106 ok else
# 107
# 107 ok else
# 108
# 108 ok if
# 109
# 109 ok else
# 110
# 110 ok else
# 111
# 111 ok else
# 112
# 112 ok else
# 113
# 113 ok else
# 114
# 114 ok else
# 115
# 115 ok else
# 116
# 116 ok else
# 117
# 117 ok if
# 118
# 118 ok else
# 119
# 119 ok else
# 120
# 120 ok if
# 121
# 121 ok if
# 122
# 122 ok if
# 123
# 123 ok if
# 124
# 124 ok else
# 125
# 125 ok else
# 126
# 126 ok if
# 127
# 127 ok else
# 128
# 128 ok else
# 129
# 129 ok else
# 130
# 130 ok else
# 131
# 131 ok else
# 132
# 132 ok else
# 133
# 133 ok else
# 134
# 134 ok else
# 135
# 135 ok else
# 136
# 136 ok else
# 137
# 137 ok else
# 138
# 138 ok else
# 139
# 139 ok else
# 140
# 140 ok else
# 141
# 141 ok else
# 142
# 142 ok if
# 143
# 143 ok else
# 144
# 144 ok else
# 145
# 145 ok else
# [{'text': '3. Fire, machinery and electric installations\n',
#   'ents': [],
#   'title': 0},
#  {'text': '\n', 'ents': [], 'title': 1},
#  {'text': 'Section 7. Scope of application of this chapter\n',
#   'ents': [],
#   'title': 2},
#  {'text': '(1) This chapter applies to vessels constructed after 2 January 1988.\n',
#   'ents': [{'start': 54, 'end': 68, 'label': 'DATE'}],
#   'title': 3},
#  {'text': '(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter.\n',
#   'ents': [{'start': 31, 'end': 45, 'label': 'DATE'}],
#   'title': 4},
#  {'text': '(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new vessel.\n',
#   'ents': [],
#   'title': 5},
#  {'text': '\n', 'ents': [], 'title': 6},
#  {'text': '0\tAmended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).\n',
#   'ents': [{'start': 27, 'end': 37, 'label': 'DATE'},
#    {'start': 60, 'end': 70, 'label': 'DATE'}],
#   'title': 7},
#  {'text': '\n', 'ents': [], 'title': 8},
#  {'text': '\n', 'ents': [], 'title': 9},
#  {'text': '\n', 'ents': [], 'title': 10},
#  {'text': 'Section 8. Fire safety\n', 'ents': [], 'title': 11},
#  {'text': '(1) Vessels constructed after 1 January 1992 shall have structural fire protection in accordance with chapter C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.\n',
#   'ents': [{'start': 30, 'end': 44, 'label': 'DATE'}],
#   'title': 12},
#  {'text': '(2) Vessels constructed before 1 January 1992 shall have structural fire protection in accordance with the rules applicable at the time of construction of the vessel.\n',
#   'ents': [{'start': 31, 'end': 45, 'label': 'DATE'}],
#   'title': 13},
#  {'text': '(3) Irrespective of the year of construction of the vessel, gasfired installations shall satisfy the requirements of Regulations of 20 October 1983 No. 1580 on safety precautions for gasfired installations, etc. operating on propane or other liquefied hydrocarbon gases used on board vessels.\n',
#   'ents': [{'start': 132, 'end': 147, 'label': 'DATE'}],
#   'title': 14},
#  {'text': '\n', 'ents': [], 'title': 15},
#  {'text': 'Section 9. Oil-fired stoves\n', 'ents': [], 'title': 16},
#  {'text': '(1) Stoves with electric power supply shall have an oil supply which shuts off automatically if:\n',
#   'ents': [],
#   'title': 17},
#  {'text': 'a)\tthe stove is over-heated (maximum 400°C in smoke gas);\n',
#   'ents': [],
#   'title': 18},
#  {'text': '\n', 'ents': [], 'title': 19},
#  {'text': 'b)\tthe flame goes out;\n', 'ents': [], 'title': 20},
#  {'text': '\n', 'ents': [], 'title': 21},
#  {'text': 'c)\ta failure occurs in the supply of air or power.\n',
#   'ents': [],
#   'title': 22},
#  {'text': '\n', 'ents': [], 'title': 23},
#  {'text': '(2) Stoves without electric power supply shall have an oil supply which shuts off automatically if\n',
#   'ents': [],
#   'title': 24},
#  {'text': 'a)\tthe stove is over-heated (maximum 400°C in smoke gas);\n',
#   'ents': [],
#   'title': 25},
#  {'text': '\n', 'ents': [], 'title': 26},
#  {'text': 'b)\tthe flame goes out.\n', 'ents': [], 'title': 27},
#  {'text': '\n', 'ents': [], 'title': 28},
#  {'text': '(3) Drip regulation stoves (regulation valve with observation hole) need not have automatic shutoff of the oil supply if the flame will go out due to the oil consumption being limited by an oil regulation valve. The installation instructions shall indicate the maximum permitted difference in height between the oil tank and the regulation valve. An oil pressure reduction valve shall be fitted if satisfactory regulation of the oil supply cannot be achieved through pressure variations. The overflow system shall be capable of receiving the full volume of the tank.\n',
#   'ents': [],
#   'title': 29},
#  {'text': '(4) The resetting of the safety function shall be manual.\n',
#   'ents': [],
#   'title': 30},
#  {'text': '(5) The installation instructions shall be kept on board. The instructions for use shall be posted near the stove.\n',
#   'ents': [],
#   'title': 31},
#  {'text': '(6) Stoves with accessories shall be installed in accordance with the installation instructions from the manufacturer.\n',
#   'ents': [],
#   'title': 32},
#  {'text': '(7) Stoves shall have smoke outlet to uptake.\n',
#   'ents': [],
#   'title': 33},
#  {'text': '\n', 'ents': [], 'title': 34},
#  {'text': 'Section 10. Installation, etc. of oilfired stove\n',
#   'ents': [],
#   'title': 35},
#  {'text': '(1) Stoves shall be securely fixed to the floor or to a fixed bench, if possible near the centre line of the vessel.\n',
#   'ents': [],
#   'title': 36},
#  {'text': '(2) Stoves without automatic shutoff of oil supply in the event of the flame going out, shall be provided with a separate oil tank of maximum 40 litres. The oil tank shall not be filled automatically, and shall be placed on the height indicated in the installation instructions.\n',
#   'ents': [],
#   'title': 37},
#  {'text': '(3) The oil tank shall have a water separator and a plug for draining off possible collection of water and shall be placed outside the space where the stove is installed.\n',
#   'ents': [],
#   'title': 38},
#  {'text': '(4) The oil pipe to the regulator shall have a filter for the separation of mud and water. The filter shall not be fitted above the stove.\n',
#   'ents': [],
#   'title': 39},
#  {'text': '(5) Pipes made of copper or equivalent material shall be used between the tank and the stove. The pipes shall be fixed and placed so as to prevent the formation of air pockets.\n',
#   'ents': [],
#   'title': 40},
#  {'text': '(6) Stoves shall have overflow openings with drain pipes and collection tank. Both the stove and the float valve, if used, shall be connected to the collection tank.\n',
#   'ents': [],
#   'title': 41},
#  {'text': '(7) Smoke uptake pipes shall have a diameter which is not less than the smoke outlet of the stove, and the piping shall be made as straight as possible.\n',
#   'ents': [],
#   'title': 42},
#  {'text': '(8) Drainage of condensed water/mud, cleaning of filters, inspection of burners and other components shall be carried out in the time intervals stipulated in the operating instructions.\n',
#   'ents': [],
#   'title': 43},
#  {'text': '(9) Spaces with a stove shall be well ventilated.\n',
#   'ents': [],
#   'title': 44},
#  {'text': '(10) On vessels of 8 to 15 metres in overall length the stove shall be inspected by an approved company within six months of being installed.\n',
#   'ents': [],
#   'title': 45},
#  {'text': '\n', 'ents': [], 'title': 46},
#  {'text': 'Section 11. Insulation of fireplaces, etc.\n',
#   'ents': [],
#   'title': 47},
#  {'text': '(1) Bulkheads shall be insulated with non-combustible material in accordance with Appendix 4.\n',
#   'ents': [],
#   'title': 48},
#  {'text': '(2) Below stoves, wooden floor or combustible floor covering shall be protected by steel or aluminium sheets covering the whole floor area under the fireplace and in front of the stove at least 15 cm from the fire door. Where the stove is placed on a bench or similar, the bench shall be protected by non-combustible material.\n',
#   'ents': [],
#   'title': 49},
#  {'text': '\n', 'ents': [], 'title': 50},
#  {'text': 'Section 12. Smoke uptake and exhaust pipes\n',
#   'ents': [],
#   'title': 51},
#  {'text': '(1) Smoke uptakes and exhaust pipes shall consist of at least 3 mm thick steel plates and shall be securely fixed. Smoke uptakes shall be carried at least 1.3 m above deck.\n',
#   'ents': [],
#   'title': 52},
#  {'text': '(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.\n',
#   'ents': [],
#   'title': 53},
#  {'text': '(3) When smoke uptake is carried along a bulkhead, the bulkhead shall be insulated with non-combustible material. Smoke uptakes shall not be placed closer than 10 cm to insulated bulkheads. Where the smoke uptake (pipe) is insulated with saucer formed rockwool or mineral wool twine of at least 2 cm thickness, the distance to the insulated bulkhead may be reduced to 5 cm.\n',
#   'ents': [],
#   'title': 54},
#  {'text': '(4) Any exhaust manifold which is not watercooled, and parts of exhaust pipes which may cause ignition, shall be insulated so that oil cannot penetrate. Where gases are watercooled, other arrangements may be accepted. Exhaust pipes shall not be closer than 2 cm to combustible material.\n',
#   'ents': [],
#   'title': 55},
#  {'text': '(5) Oil pipes shall be placed as far as possible away from exhaust pipes and hot engine parts.\n',
#   'ents': [],
#   'title': 56},
#  {'text': '\n', 'ents': [], 'title': 57},
#  {'text': 'Section 13. Insulation with non-combustible material\n',
#   'ents': [],
#   'title': 58},
#  {'text': 'Non-combustible material means a material which, when tested and evaluated in accordance with MSC.61(67) (the FTP Code), satisfies the requirements for qualifying materials as non-combustible. The insulation shall, if necessary in order to preserve the fire-insulating effect, be mounted with a sheet of galvanized steel or aluminium.\n',
#   'ents': [],
#   'title': 59},
#  {'text': '\n', 'ents': [], 'title': 60},
#  {'text': 'Section 14. Insulation of machinery spaces in wooden vessels\n',
#   'ents': [],
#   'title': 61},
#  {'text': '(1) Machinery spaces in wooden vessels shall have floors of steel or aluminium plates. Machinery spaces shall be insulated with non-combustible material or have an approved fire-extinguishing system.\n',
#   'ents': [],
#   'title': 62},
#  {'text': '(2) In machinery spaces without inside planking, wooden casings, beams and surfaces under deck as well as bulkheads forwards and aft in the machinery space shall be insulated with non-combustible material.\n',
#   'ents': [],
#   'title': 63},
#  {'text': '(3) In machinery spaces with inside planking, all woodwork shall be insulated with non-combustible material down to the lower edge of the floor. No insulation is required behind fuel oil tanks if the other insulation is fitted tightly around the tank.\n',
#   'ents': [],
#   'title': 64},
#  {'text': '(4) In vessels where the engine is not placed in a separate compartment, all combustible material which is exposed to heat from exhaust manifolds, exhaust pipes, etc. shall be insulated with non-combustible material. When an engine cover is used, this shall be insulated on the inside and be mounted with a galvanized steel or aluminium sheet.\n',
#   'ents': [],
#   'title': 65},
#  {'text': '\n', 'ents': [], 'title': 66},
#  {'text': 'Section 15. Fire-extinguishing systems in machinery spaces\n',
#   'ents': [],
#   'title': 67},
#  {'text': '(1) Vessels of 10.67 to 15 metres in overall length shall have a fire-extinguishing system. When there are persons on board, the fire-extinguishing system shall only be capable of manual release.\n',
#   'ents': [],
#   'title': 68},
#  {'text': '(2) Extinguishing medium shall be of an approved type. The amount of extinguishing medium is determined in each individual case depending on the size of the machinery space.\n',
#   'ents': [],
#   'title': 69},
#  {'text': '(3) The fire-extinguishing system shall only be capable of being released from a position outside the machinery space. The release equipment shall be clearly marked, provided with instructions for use and protected against unintentional release.\n',
#   'ents': [],
#   'title': 70},
#  {'text': '(4) Vessels of less than 10.67 metres in overall length constructed after 1 January 1992 may as an alternative be equipped with a fire-extinguishing system in accordance with guidelines laid down in chapter C14 of Nordic Boat Standard (1990).\n',
#   'ents': [{'start': 74, 'end': 88, 'label': 'DATE'}],
#   'title': 71},
#  {'text': '(5) CO2 containers and other containers for extinguishing gas which could may be hazardous in the event of a leak, with appurtenant release device, shall be placed in a separate space/locker outside the machinery space. Gastight bulkheads shall be provided to adjacent spaces and entrance from open deck. An alarm signal shall be activated automatically when the CO2 space/locker is opened. It should be ensured that no persons are present in the machinery space before the CO2 gas is released. The space/locker for release of CO2 shall have ventilation to the open air.\n',
#   'ents': [],
#   'title': 72},
#  {'text': '\n', 'ents': [], 'title': 73},
#  {'text': 'Section 16. Fire detection and alarm system\n',
#   'ents': [],
#   'title': 74},
#  {'text': '(1) Vessels of 10.67 to 15 metres in overall length, irrespective of year of construction, shall have fire detection system and fire alarm system for machinery spaces and smoke alarm system for the cabins in accordance with Appendix 5.\n',
#   'ents': [],
#   'title': 75},
#  {'text': '(2) Vessels of less than 10.67 meters in overall length shall be fitted with at least one smoke detector and one heat detector in machinery spaces, at least one smoke detector in recreational spaces, and at least one smoke detector in the wheelhouse.\n',
#   'ents': [],
#   'title': 76},
#  {'text': '\n', 'ents': [], 'title': 77},
#  {'text': 'Section 17. Fire extinguishers\n', 'ents': [], 'title': 78},
#  {'text': '(1) All vessels, irrespective of year of construction, shall have at least two approved fire extinguishers of at least 6 kg. At least one approved fire extinguisher shall be placed at a suitable place outside the machinery space and at least one approved fire extinguisher shall be placed in the accommodation spaces. For vessels without wheelhouse or accommodation spaces one fire extinguisher is sufficient.\n',
#   'ents': [],
#   'title': 79},
#  {'text': '(1) Fire extinguishers with pressurised extinguishing medium shall not be placed in accommodation spaces. Fire extinguishers which may be exposed to frost shall be of a frost-proof type.\n',
#   'ents': [],
#   'title': 80},
#  {'text': '(3) At least one spare charge shall be provided for each extinguisher. If the extinguisher is of a type that cannot be charged on board, the number of extinguishers shall be increased by 50 per cent.\n',
#   'ents': [],
#   'title': 81},
#  {'text': '(4) Fire extinguishers shall be inspected annually in accordance with NS3910. The date of the inspection shall be marked on the extinguisher.\n',
#   'ents': [],
#   'title': 82},
#  {'text': '\n', 'ents': [], 'title': 83},
#  {'text': '0\tAmended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).\n',
#   'ents': [{'start': 27, 'end': 37, 'label': 'DATE'},
#    {'start': 60, 'end': 70, 'label': 'DATE'}],
#   'title': 84},
#  {'text': '\n', 'ents': [], 'title': 85},
#  {'text': '\n', 'ents': [], 'title': 86},
#  {'text': '\n', 'ents': [], 'title': 87},
#  {'text': 'Section 18. Ventilation systems\n', 'ents': [], 'title': 88},
#  {'text': "The vessel's machinery space shall have at least two ventilators capable of being closed from deck. Cabins shall have at least two ventilators with a diameter of at least 8 cm.\n",
#   'ents': [],
#   'title': 89},
#  {'text': '\n', 'ents': [], 'title': 90},
#  {'text': 'Section 19. Materials, etc.\n', 'ents': [], 'title': 91},
#  {'text': 'Materials, varnishes, paints, etc. produced on a nitrocellulose basis or any other basis which will readily ignite are not permitted to be used anywhere on board.\n',
#   'ents': [],
#   'title': 92},
#  {'text': '\n', 'ents': [], 'title': 93},
#  {'text': 'Section 20. Storage of oil fuel and other flammable liquids\n',
#   'ents': [],
#   'title': 94},
#  {'text': '(1) Oil fuel shall be stored in tanks of steel or equivalent material.\n',
#   'ents': [],
#   'title': 95},
#  {'text': '(2) Outlets from oil fuel tanks shall be fitted with a closing valve or cock on the tank itself, which is capable of being closed from the deck. Test cocks and cocks for oil gauge glass shall be of a self-closing type. The tank shall be fitted with drip trays. In decked vessels with machinery space, filling pipes and airing pipes shall be carried through the deck and into open air.\n',
#   'ents': [],
#   'title': 96},
#  {'text': '(3) If extra fuel or other flammable liquids cannot be placed on open deck, they shall be stored in suitable containers in a well-ventilated room/locker with a door communicating only with open deck and without electrical or other sources of ignition.\n',
#   'ents': [],
#   'title': 97},
#  {'text': '\n', 'ents': [], 'title': 98},
#  {'text': 'Section 21. Materials in pipelines, etc.\n',
#   'ents': [],
#   'title': 99},
#  {'text': '(1) Seawater pipes, bilge pipes, pipes conveying oil and other pipelines required for the safety of the ship shall be made of non-combustible material. Short, flexible pipe connections made of a material which is not easily rendered ineffective by heat, may be accepted on:\n',
#   'ents': [],
#   'title': 100},
#  {'text': 'a)\tseawater pipes;\n', 'ents': [], 'title': 101},
#  {'text': '\n', 'ents': [], 'title': 102},
#  {'text': 'b)\tshort, flexible pipe connections on pipes conveying oil, when necessitated by vibrations.\n',
#   'ents': [],
#   'title': 103},
#  {'text': '\n', 'ents': [], 'title': 104},
#  {'text': '(2) Where failure of the material due to fire may lead to flooding, scuppers, sanitary discharges or other outlets which are close to the waterline shall be made of oil-resistant and reinforced materials which are not easily damaged by heat.\n',
#   'ents': [],
#   'title': 105},
#  {'text': '\n', 'ents': [], 'title': 106},
#  {'text': 'Section 22.  Machinery and piping systems\n',
#   'ents': [],
#   'title': 107},
#  {'text': '(1) Vessels constructed after 1 January 1992 shall satisfy the requirements of Nordic Boat Standard (1990)\n',
#   'ents': [{'start': 30, 'end': 44, 'label': 'DATE'}],
#   'title': 108},
#  {'text': 'a)\tC6 on bilge systems;\n', 'ents': [], 'title': 109},
#  {'text': '\n', 'ents': [], 'title': 110},
#  {'text': 'b)\tC9 on oil fuel systems;\n', 'ents': [], 'title': 111},
#  {'text': '\n', 'ents': [], 'title': 112},
#  {'text': 'c)\tC8 on engine installations; and\n', 'ents': [], 'title': 113},
#  {'text': '\n', 'ents': [], 'title': 114},
#  {'text': 'd)\tC7 and C10 on rudder and propeller arrangements.\n',
#   'ents': [],
#   'title': 115},
#  {'text': '\n', 'ents': [], 'title': 116},
#  {'text': '(2) Vessels constructed before 1 January 1992 shall as far as possible satisfy the requirements of Nordic Boat Standard (1990 chapter C6 on bilge systems.\n',
#   'ents': [{'start': 31, 'end': 45, 'label': 'DATE'}],
#   'title': 117},
#  {'text': '\n', 'ents': [], 'title': 118},
#  {'text': 'Section 23. Electrical installations\n', 'ents': [], 'title': 119},
#  {'text': '(1) Vessels of 6 to 15 metres in overall length constructed after 1 January 1992 with electrical installations with voltages of up to 50 V shall satisfy the requirements of Nordic Boat Standard (1990) C11 on electrical installations.\n',
#   'ents': [{'start': 66, 'end': 80, 'label': 'DATE'}],
#   'title': 120},
#  {'text': '(2) Vessels of 6 to 15 metres in overall length constructed before 1 January 1992 with electrical installations with voltages of up to 50 V shall be in compliance with the rules in force at the time of construction.\n',
#   'ents': [{'start': 67, 'end': 81, 'label': 'DATE'}],
#   'title': 121},
#  {'text': '(3) Vessels of 6 to 15 metres in overall length constructed between 1 January 1992 and 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in the now repealed Regulations of 1 March 1990 No. 125 for electrical installations - Maritime installations.\n',
#   'ents': [{'start': 68, 'end': 82, 'label': 'DATE'},
#    {'start': 230, 'end': 242, 'label': 'DATE'}],
#   'title': 122},
#  {'text': '(4) Vessels of 6 to 15 metres in overall length constructed after 1 January 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in Regulations of 4 December 2001 No. 1450 concerning maritime electrical installations, laid down by the Norwegian Directorate for Civil Protection.\n',
#   'ents': [{'start': 66, 'end': 80, 'label': 'DATE'},
#    {'start': 202, 'end': 217, 'label': 'DATE'}],
#   'title': 123},
#  {'text': '\n', 'ents': [], 'title': 124},
#  {'text': 'Section 24. Emergency source of power and emergency lighting, etc.\n',
#   'ents': [],
#   'title': 125},
#  {'text': '(1) Vessels of 10.67 to 15 metres in overall length constructed after 1 January 1992 shall have an emergency source of power providing satisfactory lighting for at least 2 hours to:\n',
#   'ents': [{'start': 70, 'end': 84, 'label': 'DATE'}],
#   'title': 126},
#  {'text': 'a)\tlighting in areas with life-saving appliances and launching arrangements;\n',
#   'ents': [],
#   'title': 127},
#  {'text': '\n', 'ents': [], 'title': 128},
#  {'text': 'b)\tlighting in alleyways, stairways and exits to the life-saving appliances and of the sea where the life-saving appliances are launched;\n',
#   'ents': [],
#   'title': 129},
#  {'text': '\n', 'ents': [], 'title': 130},
#  {'text': 'c)\tnecessary navigation lights; and\n', 'ents': [], 'title': 131},
#  {'text': '\n', 'ents': [], 'title': 132},
#  {'text': 'd)\trequired alarm system.\n', 'ents': [], 'title': 133},
#  {'text': '\n', 'ents': [], 'title': 134},
#  {'text': '(2) The emergency power shall be provided by one of the following two sources:\n',
#   'ents': [],
#   'title': 135},
#  {'text': 'a)\tan accumulator battery capable of carrying the load pursuant to the first paragraph without recharging or suffering an excessive voltage drop, and which is automatically connected to the emergency switchboard when the main power fails; or\n',
#   'ents': [],
#   'title': 136},
#  {'text': '\n', 'ents': [], 'title': 137},
#  {'text': 'b)\ta generator driven by a suitable type of power machinery with an independent supply of fuel, appropriate starting arrangements and driven by fuel having a flashpoint of not less than 43°C (110°F).\n',
#   'ents': [],
#   'title': 138},
#  {'text': '\n', 'ents': [], 'title': 139},
#  {'text': '(3) The entire installation shall be capable of operating even when the vessel is listed to 22.5 degrees or when the trim of the vessel is 10 degrees.\n',
#   'ents': [],
#   'title': 140},
#  {'text': '(4) Switchboards for main power and emergency power shall be clearly marked and be placed, as far as practicable, so that they cannot be exposed to water or fire. The emergency source of power shall if possible be placed above deck. If the emergency source of power is placed in the machinery space, it shall be placed above the floor and in a well-ventilated place.\n',
#   'ents': [],
#   'title': 141},
#  {'text': '(5) The emergency source of power and the emergency lighting on vessels constructed before 1 January 1992 shall be in accordance with the rules in force at the time of construction.\n',
#   'ents': [{'start': 91, 'end': 105, 'label': 'DATE'}],
#   'title': 142},
#  {'text': '\n', 'ents': [], 'title': 143},
#  {'text': 'Section 25. Equivalents\n', 'ents': [], 'title': 144},
#  {'text': 'Vessels constructed pursuant to Nordic Boat Standard (1990) are considered to satisfy the requirements of sections 18, 19 and 20.\n',
#   'ents': [],
#   'title': 145}]

# %% [markdown]
# # identify_date_in_spacy_lines

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import identify_date

from identify_date import identify_date_in_spacy_lines

importlib.reload(identify_date)

################
################

result = identify_date_in_spacy_lines(forward_lines_as_spacy_ner_format)
#print(result)

options = {"colors": {"DATE": "yellow"}}

# display result with spacy styling
from spacy import displacy
displacy.render(result, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">3. Fire, machinery and electric installations</br></div>
#
# <h2 style="margin: 0">1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Section 7. Scope of application of this chapter</br></div>
#
# <h2 style="margin: 0">3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) This chapter applies to vessels constructed after
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 January 1988
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></div>
#
# <h2 style="margin: 0">4</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Vessels constructed before
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 January 1988
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter.</br></div>
#
# <h2 style="margin: 0">5</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new vessel.</br></div>
#
# <h2 style="margin: 0">6</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">7</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">0	Amended by Regulation of
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 May 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  No.. 445 (in force on
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 May 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).</br></div>
#
# <h2 style="margin: 0">8</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">9</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">10</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">11</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Section 8. Fire safety</br></div>
#
# <h2 style="margin: 0">12</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Vessels constructed after
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 January 1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  shall have structural fire protection in accordance with chapter C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.</br></div>
#
# <h2 style="margin: 0">13</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Vessels constructed before
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 January 1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  shall have structural fire protection in accordance with the rules applicable at the time of construction of the vessel.</br></div>
#
# <h2 style="margin: 0">14</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Irrespective of the year of construction of the vessel, gasfired installations shall satisfy the requirements of Regulations of
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 October 1983
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  No. 1580 on safety precautions for gasfired installations, etc. operating on propane or other liquefied hydrocarbon gases used on board vessels.</br></div>
#
# <h2 style="margin: 0">15</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">16</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Section 9. Oil-fired stoves</br></div>
#
# <h2 style="margin: 0">17</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Stoves with electric power supply shall have an oil supply which shuts off automatically if:</br></div>
#
# <h2 style="margin: 0">18</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">a)	the stove is over-heated (maximum 400°C in smoke gas);</br></div>
#
# <h2 style="margin: 0">19</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">20</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">b)	the flame goes out;</br></div>
#
# <h2 style="margin: 0">21</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">22</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">c)	a failure occurs in the supply of air or power.</br></div>
#
# <h2 style="margin: 0">23</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">24</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Stoves without electric power supply shall have an oil supply which shuts off automatically if</br></div>
#
# <h2 style="margin: 0">25</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">a)	the stove is over-heated (maximum 400°C in smoke gas);</br></div>
#
# <h2 style="margin: 0">26</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">27</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">b)	the flame goes out.</br></div>
#
# <h2 style="margin: 0">28</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></div>
#
# <h2 style="margin: 0">29</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Drip regulation stoves (regulation valve with observation hole) need not have automatic shutoff of the oil supply if the flame will go out due to the oil consumption being limited by an oil regulation valve. The installation instructions shall indicate the maximum permitted difference in height between the oil tank and the regulation valve. An oil pressure reduction valve shall be fitted if satisfactory regulation of the oil supply cannot be achieved through pressure variations. The overflow system shall be capable of receiving the full volume of the tank.</br></div>
#
# <h2 style="margin: 0">30</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(4) The resetting of the safety function shall be manual.</br></div>
#
# <h2 style="margin: 0">31</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(5) The installati
