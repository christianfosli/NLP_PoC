# %% [markdown]
# # Initialize

# %%
# !pip install -U spacy==2.3.5

# %%
import spacy
print(spacy.__version__)
# Out:
# 2.3.5

# %%
# Had to run this to make something below work.
# This is a donwgrade of numpy to a version without a bug.
# This is a temp solution until a new version of numpy has solved the bug.
# !pip install numpy==1.19.3 --user

# %% [markdown]
# # api input

# %%
text_service_chapter_input = {
    "sections": [
        {
            "parts": [
                {
                    "referenceId": "/paragraf/1/ledd/1",
                    "content": "\nForskriften gjelder for norske\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/paragraf/1/ledd/1/liste/a",
                            "content": "lasteskip med bruttotonnasje under 500",
                            "uid": "0a734b45-0db7-40dd-b197-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/paragraf/1/ledd/1/liste/b",
                            "content": "fiskefartøy med bruttotonnasje under 500",
                            "uid": "35e1c92f-8a8d-427c-b198-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/2",
                            "language": "nb"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/paragraf/1/ledd/1/liste/c",
                            "content": "passasjerskip i utenriksfart sertifisert for 12 eller færre passasjerer",
                            "uid": "f88bfb67-62f3-4026-b199-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/3",
                            "language": "nb"
                        },
                        {
                            "number": "d)",
                            "referenceId": "/paragraf/1/ledd/1/liste/d",
                            "content": "roro-passasjerskip sertifisert for 12 eller færre passasjerer",
                            "uid": "293f1144-b425-4334-b19a-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/4",
                            "language": "nb"
                        },
                        {
                            "number": "e)",
                            "referenceId": "/paragraf/1/ledd/1/liste/e",
                            "content": "passasjerskip i innenriksfart sertifisert for 100 eller færre passasjerer",
                            "uid": "0ab1deaa-c8a7-43de-b19b-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/5",
                            "language": "nb"
                        },
                        {
                            "number": "f)",
                            "referenceId": "/paragraf/1/ledd/1/liste/f",
                            "content": "fartøy over 24 meter som brukes utenfor næringsvirksomhet.",
                            "uid": "7322b87b-ab36-4589-b19c-08d8d72270fa",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/6",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "30ef342a-ee0e-4258-582b-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/1/ledd/2",
                    "content": "Forskriften gjelder tilsvarende for utenlandske skip som opererer i norsk territorialfarvann.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6d918e9a-cd14-4541-582c-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/1/ledd/3",
                    "content": "Forskriften gjelder ikke for lektere, for statlige skip som brukes utenfor næringsvirksomhet, eller for skip som tilhører Forsvaret eller benyttes i dets tjeneste.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "af2aefdb-63a8-48af-582d-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/3",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/1",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p1",
            "title": "Virkeområde",
            "uid": "01c330ab-f4ee-435e-f772-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/2/ledd/1",
                    "content": "Rederiet skal etablere, gjennomføre og videreutvikle et dokumenterbart sikkerhetsstyringssystem i samsvar med denne forskriften.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f1247784-c9f8-4d09-582e-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/2/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/2/ledd/2",
                    "content": "Rederiet skal, for å sikre forsvarlig drift, definere og dokumentere ansvar og myndighet for alt personell som kan påvirke helse, miljø og sikkerhet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "201c3605-2c1e-4eb2-582f-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/2/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/2",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p2",
            "title": "Rederiets plikt til å etablere, gjennomføre og videreutvikle et sikkerhetsstyringssystem",
            "uid": "9ef3171f-5f62-4d2b-f773-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/2",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/3/ledd/1",
                    "content": "Formålet med sikkerhetsstyringssystemet er å gjøre det lettere for rederiet å vurdere risiko og følge opp de daglige kontrollrutinene ved bruk av en systematisk fremgangsmåte. Sikkerhetsstyringssystemet skal på denne måten gi bedre oversikt i den daglige driften og ivareta sikkerhet til sjøs, hindre personskader eller tap av menneskeliv, unngå skade på miljøet, særlig havmiljøet, og på materielle verdier.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "45bd2e6d-2c63-4731-5830-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/3/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/3",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p3",
            "title": "Formålet med sikkerhetsstyringssystemet",
            "uid": "1a752428-fdce-4ca4-f774-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/3",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/4/ledd/1",
                    "content": "Rederiet skal definere og dokumentere skipsførerens plikter og myndighet. Skipsføreren har den øverste myndigheten om bord. Skipsføreren skal medvirke til å gjennomføre og følge opp sikkerhetsstyringssystemet og at sikkerhetssystemet fungerer etter sin hensikt om bord.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "d9255419-fcbc-4ea6-5831-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/4/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/4/ledd/2",
                    "content": "Skipsfører skal be rederiet om bistand når dette er nødvendig.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "add0fb44-3207-4049-5832-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/4/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/4",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p4",
            "title": "Skipsførerens plikter og myndighet",
            "uid": "6b53b25b-a274-4ea3-f775-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/4",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/5/ledd/1",
                    "content": "Rederiet skal sørge for at skipsføreren er kompetent til å ha kommandoen om bord og er fullt fortrolig med rederiets sikkerhetsstyringssystem. Videre skal rederiet sørge for at skipsføreren får nødvendig støtte og ressurser til å utføre oppgavene sine på en forsvarlig måte.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b5af3e72-e65b-463b-5833-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/5/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/5/ledd/2",
                    "content": "Rederiet skal sørge for at hvert skip er tilstrekkelig bemannet med arbeidstakere som innehar rett kompetanse, og som er kvalifiserte, sertifiserte og medisinsk skikket i samsvar med gjeldende regler.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8624fa37-9619-4251-5834-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/5/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/5/ledd/3",
                    "content": "Rederiet skal sørge for at nødvendig opplæring blir gitt, og at en tilstrekkelig grad av familiarisering om bord blir praktisert.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "4f8eb5c2-3ed8-4f56-5835-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/5/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/5/ledd/4",
                    "content": "Rederiet skal gi personellet på skipet tilgang til sikkerhetsstyringssystemet på et arbeidsspråk de forstår.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "41662b83-2ad4-41cb-5836-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/5/part/4",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/5",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p5",
            "title": "Ressurser og de som har sitt arbeid om bord - Opplæring og kompetanseutvikling",
            "uid": "71d74ac2-0380-44f0-f776-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/5",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/6/ledd/1",
                    "content": "Rederiet skal utarbeide instrukser, prosedyrer og eventuelle sjekklister som er tilpasset skipets og rederiets drift. Det skal utarbeides risikovurderinger for operasjoner om bord som påvirker sikkerhet, herunder miljøsikkerhet. Oppgaver knyttet til disse operasjonene skal tildeles kvalifisert personell.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "c61237e0-0203-4ba3-5837-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/6/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/6",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p6",
            "title": "Operasjon om bord og risikovurderinger",
            "uid": "5497a795-a4b3-488d-f777-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/6",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/7/ledd/1",
                    "content": "Rederiet skal innføre framgangsmåter for å identifisere, beskrive og reagere på mulige farer, ulykker og nødssituasjoner om bord.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3ce234ef-2325-4325-5838-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/7/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/7/ledd/2",
                    "content": "Rederiet skal lage en plan for opplæring, trening og øvelser i beredskapssammenheng.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a17e8d7e-a0e6-4f47-5839-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/7/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/7",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p7",
            "title": "Beredskap",
            "uid": "221612c0-96ec-40bf-f778-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/7",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/8/ledd/1",
                    "content": "Rederiet skal ved hjelp av sikkerhetsstyringssystemet analysere avvik, ulykker og farlige hendelser med det formål å hindre gjentakelse og gjennomføre korrektive og forebyggende tiltak.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "26bfbed2-26a0-49a6-583a-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/8/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/8/ledd/2",
                    "content": "Rederiet må kunne dokumentere sin fremgangsmåte for avviks- og hendelsesbehandling.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b2e47046-41b3-4135-583b-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/8/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/8",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p8",
            "title": "Avviks- og hendelsesbehandling",
            "uid": "ac0de70a-e920-4120-f779-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/8",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/9/ledd/1",
                    "content": "Rederiet skal utvikle, følge opp og dokumentere et vedlikeholdssystem som er tilpasset driftsformen til skipet. Vedlikeholdssystemet skal sikre at skip og utstyr vedlikeholdes i samsvar med gjeldende krav.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "412578f2-736a-4a85-583c-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/9/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/9/ledd/2",
                    "content": "Rederiet skal sørge for å identifisere utstyr og tekniske systemer som kan forårsake farlige situasjoner i tilfelle av plutselig svikt. Sikkerhetsstyringssystemet skal omfatte tiltak for å forbedre påliteligheten til slikt utstyr eller slike systemer. Tiltakene skal som minimum omfatte regelmessig prøving av reservesystemer og -utstyr eller av tekniske systemer som ikke er i kontinuerlig drift.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e311bc99-3255-49db-583d-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/9/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/9",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p9",
            "title": "Vedlikehold og kritisk utstyr",
            "uid": "da30a1fc-d659-4e16-f77a-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/9",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/10/ledd/1",
                    "content": "Rederiet skal sørge for at gyldige dokumenter er tilgjengelige på alle aktuelle steder, og at endringer i dokumenter gjennomgås og godkjennes av personer som er tildelt denne oppgaven. Foreldede dokumenter skal fjernes.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e380bc64-8e10-4bbd-583e-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/10/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/10",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p10",
            "title": "Relevant dokumentasjon tilgjengelig",
            "uid": "7b7d0ac0-ff39-4bdd-f77b-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/10",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/11/ledd/1",
                    "content": "Rederiet skal ha en årlig, verifiserbar gjennomgang av sikkerhetsstyringssystemet for å vurdere om sikkerhetsstyringssystemet fungerer i tråd med formålet og om det er behov for forbedringer.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "c02eaee8-650e-4a4e-583f-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/11/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/11",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p11",
            "title": "Evaluering av systemet",
            "uid": "6f569238-edc1-4ce8-f77c-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/11",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/paragraf/12/ledd/1",
                    "content": "Forskriften trer i kraft 1. januar 2017.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3c9926d9-83c4-43bd-5840-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/12/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/paragraf/12/ledd/2",
                    "content": "Sikkerhetsstyringssystem i samsvar med forskriften skal være etablert og tatt i bruk innen 1. juli 2017. For skip som skal føre mer enn 50 passasjerer skal rederiet utarbeide. overstyrmann på skip med bruttotonnasje opp til 3000 i ubegrenset fartsområde. skip med bruttotonnasje over 500. Slike fartøy i innenriksfart uansett byggedato med bruttotonnasje 50 eller mer.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6cb9ece6-6f1e-4798-5841-08d8d72270ec",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/12/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/paragraf/12",
            "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1/p12",
            "title": "Ikrafttredelse",
            "uid": "1c4548b4-cb02-4556-f77d-08d8d72270eb",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/12",
            "language": "nb"
        }
    ],
    "referenceId": "/kapittel/1",
    "referenceUrl": "https://lovdata.no/forskrift/2016-12-16-1770/k1",
    "title": "Sikkerhetsstyring",
    "uid": "39fcbd07-bd6a-465b-84a6-08d8d72270eb",
    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1",
    "language": "nb"
}

# %% [markdown]
# # transform_chapter_from_text_service_to_spacy_format

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import transform_chapter_from_text_service_to_spacy_format

importlib.reload(transform_text_service_input_to_spacy_format)

################
################

forward_text_transformed_to_spacy_format = transform_chapter_from_text_service_to_spacy_format(text_service_chapter_input)

print(forward_text_transformed_to_spacy_format)
# Out:
# [{'text': '\nForskriften gjelder for norske\n', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1'}, {'text': 'lasteskip med bruttotonnasje under 500', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/1'}, {'text': 'fiskefartøy med bruttotonnasje under 500', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/2'}, {'text': 'passasjerskip i utenriksfart sertifisert for 12 eller færre passasjerer', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/3'}, {'text': 'roro-passasjerskip sertifisert for 12 eller færre passasjerer', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/1
# ...

# %% [markdown]
# # analyse text

# %%
options = {"colors": {"VESSEL": "darksalmon"}}

# %%
#
# Display all spacy lines, with and without pattern match.
#

#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import spacy_matching_rule_identify_VESSEL_no

from spacy_matching_rule_identify_VESSEL_no import identify_VESSEL_in_norwegian_spacy_lines

importlib.reload(spacy_matching_rule_identify_VESSEL_no)

################
################

forward_result_with_date_in_norwegian = identify_VESSEL_in_norwegian_spacy_lines(forward_text_transformed_to_spacy_format)

# display result with spacy styling
from spacy import displacy
displacy.render(forward_result_with_date_in_norwegian, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"></br>Forskriften gjelder for norske</br></div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lasteskip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">VESSEL</span>
# </mark>
#  med bruttotonnasje under 500</div>
#
# ...

# %% [markdown]
# # We only need the spacy lines with identified 'WATER_VESSEL' and 'LENGTH'

# %%
forward_filtered_result_with_only_the_things_we_are_looking_for = [
    spacy_line for spacy_line in forward_result_with_date_in_norwegian if any("VESSEL" == x['label'] for x in spacy_line['ents'])
    ]

#print(forward_filtered_result_with_only_the_things_we_are_looking_for)

# display result with spacy styling
from spacy import displacy
displacy.render(forward_filtered_result_with_only_the_things_we_are_looking_for, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lasteskip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">VESSEL</span>
# </mark>
#  med bruttotonnasje under 500</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2016/12/16/1770/chapter/1/section/1/part/1/subpart/6</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %% [markdown]
# # We now know that every line in filtered list have what we look for

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import get_data_from_text_service_item_url

importlib.reload(transform_text_service_input_to_spacy_format)

import spacy
from spacy.lang.en import English

####
nlp = English()
forward_result = []
###

for line in forward_filtered_result_with_only_the_things_we_are_looking_for:

    # Get NLP data from line
    text_service_url = line['title']
    text = line['text']
    ents = line['ents'] # discovered enteties in the line
    last_index_number_of_ents = len(ents)-1
    doc = nlp(text)

    # Get metadata from URL
    result_text_service_url = get_data_from_text_service_item_url(text_service_url)
    metadata_from_url = {}
    if "regulation_year" in result_text_service_url:
        metadata_from_url['regulation_year'] = result_text_service_url['regulation_year']
    if "regulation_month" in result_text_service_url:
        metadata_from_url['regulation_month'] = result_text_service_url['regulation_month']
    if "regulation_day" in result_text_service_url:
        metadata_from_url['regulation_day'] = result_text_service_url['regulation_day']
    if "regulation_id" in result_text_service_url:
        metadata_from_url['regulation_id'] = result_text_service_url['regulation_id']
    if "chapter_number" in result_text_service_url:
        metadata_from_url['chapter_number'] = result_text_service_url['chapter_number']
    if "section_number" in result_text_service_url:
        metadata_from_url['section_number'] = result_text_service_url['section_number']
    if "part_number" in result_text_service_url:
        metadata_from_url['part_number'] = result_text_service_url['part_number']
    if "sub_part_number" in result_text_service_url:
        metadata_from_url['sub_part_number'] = result_text_service_url['sub_part_number']

    # For each ent in line
    for ent_index_number, ent in enumerate(ents):

        ent_label = ent['label']
        ent_start = ent['start']
        ent_end = ent['end']

        ent_text = text[ent_start:ent_end] # same as: doc[ent_token_span.start:ent_token_span.end]
        ent_doc = nlp(ent_text)
        words_in_doc_count = len(ent_doc)

        ent_token_span = doc.char_span(ent_start,ent_end)
        ent_token_span_start = ent_token_span.start
        ent_token_span_end = ent_token_span.end
        
        #print(ent_text + " - " + ent_label + " (" + str(ent_token_span_start) + ":" + str(ent_token_span_end) + ")")

        #
        # Statment concluder
        #

        if ent_label == "VESSEL":

            detection_with_url_metadata = dict(metadata_from_url)
            detection_with_url_metadata["vessel_text"] = ent_text
            forward_result.append(detection_with_url_metadata)

forward_result
# Out:
# [{'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '1',
#   'sub_part_number': '1',
#   'vessel_text': 'lasteskip'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '1',
#   'sub_part_number': '6',
#   'vessel_text': 'fartøy'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '2',
#   'vessel_text': 'skip'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '3',
#   'vessel_text': 'skip'},
#  {'regulation_year': '2016',
# ...

# %% [markdown]
# # Create API responce

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import api_controller_identify_VESSEL_in_text_service_norwegian_chapter

from api_controller_identify_VESSEL_in_text_service_norwegian_chapter import create_api_response_for_post_identify_VESSEL_in_text_service_norwegian_chapter

importlib.reload(api_controller_identify_VESSEL_in_text_service_norwegian_chapter)

#####

create_api_response_for_post_identify_VESSEL_in_text_service_norwegian_chapter(forward_filtered_result_with_only_the_things_we_are_looking_for)
# Out:
# [{'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '1',
#   'sub_part_number': '1',
#   'vessel_text': 'lasteskip'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '1',
#   'sub_part_number': '6',
#   'vessel_text': 'fartøy'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '2',
#   'vessel_text': 'skip'},
#  {'regulation_year': '2016',
#   'regulation_month': '12',
#   'regulation_day': '16',
#   'regulation_id': '1770',
#   'chapter_number': '1',
#   'section_number': '1',
#   'part_number': '3',
#   'vessel_text': 'skip'},
#  {'regulation_year': '2016',
# ...
