# %%
# !pip install nltk

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.5

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

# %%
#
# Download
#

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#
# Lastar inn teksten vi jobbar med
#

with open('./Input text - Chapter 3.txt', 'r') as f:
    file_contents = f.read()
    
print(file_contents)
# Out:
# 3. Fire, machinery and electric installations
# Section 7. Scope of application of this chapter
# (1) This chapter applies to vessels constructed after 2 January 1988.
# (2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules
# applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of
# this chapter.
# (3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new
# vessel.
# 0 Amended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).
# Section 8. Fire safety
# (1) Vessels constructed after 1 January 1992 shall have structural fire protection in accordance with chapter
# C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.
# (2) Vessels constructed before 1 January 1992 shall have structural fire protection in accordance with the rules
# ...

# %%
#
# Splitte opp linjehopp frå tekst fil.
# Eksempel: Fire, machinery and electric installations\nSection 7.
#

sentences = file_contents.split('\n')
sentences
# Out:
# ['3. Fire, machinery and electric installations',
#  'Section 7. Scope of application of this chapter',
#  '(1) This chapter applies to vessels constructed after 2 January 1988.',
#  '(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules',
#  'applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of',
#  'this chapter.',
#  '(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new',
#  'vessel.',
#  '0 Amended by Regulation of 4 May 2015 No.. 445 (in force on 6 May 2015).',
#  'Section 8. Fire safety',
#  '(1) Vessels constructed after 1 January 1992 shall have structural fire protection in accordance with chapter',
#  'C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.',
# ...

# %%
#
# Remove numbers from the sentences using regular expression
#

import re

documents_list = []

for line in sentences:
    sentence = line.strip() # Remove spaces at the beginning and at the end of the string
    new_sentence = re.sub(r"\d","", sentence)
    documents_list.append(new_sentence)
    
documents_list
# Out:
# ['. Fire, machinery and electric installations',
#  'Section . Scope of application of this chapter',
#  '() This chapter applies to vessels constructed after  January .',
#  '() Vessels constructed before  January  shall be constructed and equipped in accordance with the rules',
#  'applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of',
#  'this chapter.',
#  '() When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new',
#  'vessel.',
#  ' Amended by Regulation of  May  No..  (in force on  May ).',
#  'Section . Fire safety',
#  '() Vessels constructed after  January  shall have structural fire protection in accordance with chapter',
#  'C of Nordic Boat Standard (), unless otherwise provided by the individual provisions of this chapter.',
#  '() Vessels constructed before  January  shall have structural fire protection in accordance with the rules',
# ...

# %%
# Doing this to see patterns that can be removed

test = set(documents_list)
test
# Out:
# {' Amended by Regulation of  May  No..  (in force on  May ).',
#  ' concerning maritime electrical installations, laid down by the Norwegian Directorate for Civil Protection.',
#  '() All vessels, irrespective of year of construction, shall have at least two approved fire extinguishers of at',
#  '() Any exhaust manifold which is not watercooled, and parts of exhaust pipes which may cause ignition, shall',
#  '() At least one spare charge shall be provided for each extinguisher. If the extinguisher is of a type that cannot',
#  '() Below stoves, wooden floor or combustible floor covering shall be protected by steel or aluminium sheets',
#  '() Bulkheads shall be insulated with non-combustible material in accordance with Appendix .',
#  '() CO containers and other containers for extinguishing gas which could may be hazardous in the event of a',
#  '() Drainage of condensed water/mud, cleaning of filters, inspection of burners and other components shall be',
# ...

# %%
#
# Example to remove something simple without regex by just looping through
#

edit_sentences = documents_list
documents_list = []

for line in edit_sentences:
    
    # Bytte eller fjerne teikn
    edited_line = line.replace('() ','')
    edited_line = line.replace('/',' ') # eksempel: splitte sånt som dette i to -> 'space/locker'
    documents_list.append(edited_line)
    
documents_list
# Out:
# ['. Fire, machinery and electric installations',
#  'Section . Scope of application of this chapter',
#  '() This chapter applies to vessels constructed after  January .',
#  '() Vessels constructed before  January  shall be constructed and equipped in accordance with the rules',
#  'applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of',
#  'this chapter.',
#  '() When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new',
#  'vessel.',
#  ' Amended by Regulation of  May  No..  (in force on  May ).',
#  'Section . Fire safety',
#  '() Vessels constructed after  January  shall have structural fire protection in accordance with chapter',
#  'C of Nordic Boat Standard (), unless otherwise provided by the individual provisions of this chapter.',
#  '() Vessels constructed before  January  shall have structural fire protection in accordance with the rules',
# ...

# %%
#
# Get the stop words
#

stop_words = set(stopwords.words('english'))

# Legger til alt som ikkje er til hjelp for å finne dobbeltord
stop_words.update(['.',',','(',')','section','°c','c',';','..',':','b','c','the','mm','cm','in',"'s",'no','an','etc','where' ])

stop_words
# Out:
# {"'s",
#  '(',
#  ')',
#  ',',
#  '.',
#  '..',
#  ':',
#  ';',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'b',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'c',
#  'can',
#  'cm',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'etc',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
# ...

# %%
stopped_tokens = []
not_stopped_tokens = []

for doc in documents_list:
    tokens = word_tokenize(doc)
    stopped_tokens = stopped_tokens + [token for token in tokens if token.lower() in stop_words]
    not_stopped_tokens = not_stopped_tokens + [token for token in tokens if token.lower() not in stop_words]
    
#print(stopped_tokens)
print(not_stopped_tokens)
# Out:
# ['Fire', 'machinery', 'electric', 'installations', 'Scope', 'application', 'chapter', 'chapter', 'applies', 'vessels', 'constructed', 'January', 'Vessels', 'constructed', 'January', 'shall', 'constructed', 'equipped', 'accordance', 'rules', 'applicable', 'time', 'construction', 'vessel', 'unless', 'otherwise', 'provided', 'individual', 'provisions', 'chapter', 'vessel', 'substantially', 'altered', 'modified', 'vessel', 'shall', 'comply', 'requirements', 'new', 'vessel', 'Amended', 'Regulation', 'May', 'force', 'May', 'Fire', 'safety', 'Vessels', 'constructed', 'January', 'shall', 'structural', 'fire', 'protection', 'accordance', 'chapter', 'Nordic', 'Boat', 'Standard', 'unless', 'otherwise', 'provided', 'individual', 'provisions', 'chapter', 'Vessels', 'constructed', 'January', 'shall', 'structural', 'fire', 'protection', 'accordance', 'rules', 'applicable', 'time', 'construction', 'vessel', 'Irrespective', 'year', 'construction', 'vessel', 'gasfired', 'installations', 'shall', 'sati
# ...

# %%
from nltk import bigrams
nltk_bigrams = bigrams(not_stopped_tokens)
list(nltk_bigrams)
# Out:
# [('Fire', 'machinery'),
#  ('machinery', 'electric'),
#  ('electric', 'installations'),
#  ('installations', 'Scope'),
#  ('Scope', 'application'),
#  ('application', 'chapter'),
#  ('chapter', 'chapter'),
#  ('chapter', 'applies'),
#  ('applies', 'vessels'),
#  ('vessels', 'constructed'),
#  ('constructed', 'January'),
#  ('January', 'Vessels'),
#  ('Vessels', 'constructed'),
#  ('constructed', 'January'),
#  ('January', 'shall'),
#  ('shall', 'constructed'),
#  ('constructed', 'equipped'),
#  ('equipped', 'accordance'),
#  ('accordance', 'rules'),
#  ('rules', 'applicable'),
#  ('applicable', 'time'),
#  ('time', 'construction'),
#  ('construction', 'vessel'),
#  ('vessel', 'unless'),
#  ('unless', 'otherwise'),
#  ('otherwise', 'provided'),
#  ('provided', 'individual'),
#  ('individual', 'provisions'),
#  ('provisions', 'chapter'),
#  ('chapter', 'vessel'),
#  ('vessel', 'substantially'),
#  ('substantially', 'altered'),
#  ('altered', 'modified'),
#  ('modified', 'vessel'),
# ...

# %%
#TODO: fjerne bøyingar

# %%
from nltk.collocations import BigramAssocMeasures
from nltk.collocations import BigramCollocationFinder

bigram_measures = BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(not_stopped_tokens)

# return the top n-grams with the highest PMI
#finder.nbest(bigram_measures.likelihood_ratio, 100) # talet er ein limit
finder.nbest(bigram_measures.likelihood_ratio, 1000)
# Out:
# [('constructed', 'January'),
#  ('overall', 'length'),
#  ('metres', 'overall'),
#  ('non-combustible', 'material'),
#  ('satisfy', 'requirements'),
#  ('Boat', 'Standard'),
#  ('Nordic', 'Boat'),
#  ('machinery', 'space'),
#  ('electrical', 'installations'),
#  ('Vessels', 'metres'),
#  ('voltages', 'V'),
#  ('fire-extinguishing', 'system'),
#  ('source', 'power'),
#  ('steel', 'aluminium'),
#  ('insulated', 'non-combustible'),
#  ('length', 'constructed'),
#  ('formed', 'rockwool'),
#  ('life-saving', 'appliances'),
#  ('least', 'one'),
#  ('installation', 'instructions'),
#  ('time', 'construction'),
#  ('installations', 'voltages'),
#  ('combustible', 'material'),
#  ('Fire', 'extinguishers'),
#  ('machinery', 'spaces'),
#  ('emergency', 'source'),
#  ('Vessels', 'constructed'),
#  ('exhaust', 'pipes'),
#  ('Smoke', 'uptakes'),
#  ('alarm', 'system'),
#  ('year', 'construction'),
#  ('oil', 'supply'),
#  ('shall', 'insulated'),
#  ('Amended', 'Regulation'),
# ...

# %%
# The simplest method is to rank the most frequent bigrams.
# Source: https://medium.com/@nicharuch/collocations-identifying-phrases-that-act-like-individual-words-in-nlp-f58a93a2f84a

import pandas as pd 

#bigrams
bigram_freq = finder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
bigramFreqTable

# However, a common issue with this is adjacent spaces, stop words, articles, prepositions or pronouns are common and are not meaningful.
# Out:
#                            bigram  freq
# 10         (constructed, January)    13
# 317   (non-combustible, material)    10
# 302             (overall, length)    10
# 301             (metres, overall)     9
# 208               (shall, placed)     9
# ...                           ...   ...
# 416              (carried, along)     1
# 417             (along, bulkhead)     1
# 418          (bulkhead, bulkhead)     1
# 419             (bulkhead, shall)     1
# 1053     (requirements, sections)     1
#
# [1054 rows x 2 columns]

# %%
# To fix this, we filter out for collocations not containing stop words and filter for only the following structures:
# Bigrams: (Noun, Noun), (Adjective, Noun)
# This is a common structure used in literature and generally works well.

#function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    
    if '-pron-' in ngram or 't' in ngram:
        return False
    
    for word in ngram:
        if word in stop_words or word.isspace():
            return False
        
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        return True
    else:
        return False

#filter bigrams
filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]
filtered_bi
# Out:
#                            bigram  freq
# 317   (non-combustible, material)    10
# 302             (overall, length)    10
# 518            (machinery, space)     9
# 911   (electrical, installations)     7
# 560             (Vessels, metres)     7
# ...                           ...   ...
# 409              (material, pipe)     1
# 411                (deck, outlet)     1
# 414               (collar, smoke)     1
# 418          (bulkhead, bulkhead)     1
# 1053     (requirements, sections)     1
#
# [513 rows x 2 columns]

# %%
pd.DataFrame(filtered_bi).to_csv("output - Get nouns - Two words.csv", header=None, index=None)
