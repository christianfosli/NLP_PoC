# %% [markdown]
# # Initialize

# %%
# !pip install -U spacy==2.3.5
# Out:
# Requirement already satisfied: spacy==2.3.5 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (2.3.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (7.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (2.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (1.19.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (4.54.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (0.7.4)
# Requirement already satisfied: setuptools in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (49.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (2.25.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from spacy==2.3.5) (1.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (4.0.0)

# %%
import spacy
print(spacy.__version__)
# Out:
# 2.3.5

# %%
# Had to run this to make something below work.
# This is a donwgrade of numpy to a version without a bug.
# This is a temp solution until a new version of numpy has solved the bug.
# !pip install numpy==1.19.3 --user
# Out:
# Requirement already satisfied: numpy==1.19.3 in c:\users\lhustvei\appdata\local\programs\python\python39\lib\site-packages (1.19.3)

# %% [markdown]
# # api input

# %%
text_service_chapter_input = {
    "sections": [
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/1",
                    "content": "(1) Dette kapittelet gjelder for fartøy bygget etter 2. januar 1988.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "4570e953-f2e9-484d-ab82-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/2",
                    "content": "(2) Fartøy som er bygget før 2. januar 1988 skal være bygget og utrustet etter reglene som gjaldt da fartøyet ble bygget, med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "102a1f75-62c1-461f-ab83-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/3",
                    "content": "(3) Når et fartøy forandres eller ombygges i vesentlig omfang, skal fartøyet oppfylle kravene til nytt fartøy.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "60206eaf-315e-484c-ab84-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/3",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/7",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p7",
            "title": "Kapittelets anvendelsesområde",
            "uid": "e13e5fb8-d7bb-4c7f-2eb0-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/1",
                    "content": "(1) Fartøy bygget etter 1. januar 1992 skal brannsikres konstruksjonsmessig i henhold til kapittel Y14 i Nordisk Båt Standard (1990), med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "9882f165-4cad-4040-ab85-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/2",
                    "content": "(2) Fartøy som er bygget før 1. januar 1992 skal brannsikres konstruksjonsmessig etter reglene som gjaldt da fartøyet ble bygget.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "87fc5267-7585-4fb8-ab86-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/3",
                    "content": "(3) Uavhengig av fartøyets byggedato skal gassfyrte anlegg skal tilfredsstille forskrift 20. oktober 1983 nr. 1580 om sikringstiltak for gassfyrte anlegg m.m. som bruker propan eller andre lette kullvannstoffer anvendt ombord på fartøy.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "03c25abb-be09-4000-ab87-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/3",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/8",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p8",
            "title": "Brannsikring",
            "uid": "2fd8668d-8ac2-4b44-2eb1-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/1",
                    "content": "(1) Ovner med elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/a",
                            "content": "ovnen overopphetes (maksimum 400 °C i røykgass),",
                            "uid": "c09f51e0-3c14-46ca-5837-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/b",
                            "content": "flammen slukker,",
                            "uid": "59f7a94f-6152-4d04-5838-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/2",
                            "language": "nb"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/c",
                            "content": "det oppstår svikt i lufttilførsel eller kraftforsyning.",
                            "uid": "305af0c7-315c-4619-5839-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/3",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "7ac4a283-b24e-4e94-ab88-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/2",
                    "content": "(2) Ovner uten elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/2/liste/a",
                            "content": "ovnen overopphetes (maksimum 400 °C i røykgass),",
                            "uid": "ce5ab177-7b84-4a4f-583a-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/2/liste/b",
                            "content": "flammen slukker.",
                            "uid": "0d311b30-1dec-48ce-583b-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/2",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "ebabc9a1-4724-4931-ab89-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/3",
                    "content": "(3) Ovner med dryppregulering (stillkran med seglass), trenger ikke automatisk stengning av oljetilførsel når flammen slukker ved at oljeforbruket er begrenset av en oljestillerventil. Maksimalt tillatt høydeforskjell mellom oljetank og stillkran skal fremgå av installasjonsbeskrivelsen. Oljetrykksreduksjonsventil skal monteres når en tilfredsstillende oljeregulering ikke oppnås på grunn av trykkvariasjoner. Overflomssystemet skal kunne motta hele tankens volum.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6f62dad8-2f56-4379-ab8a-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/4",
                    "content": "(4) Tilbakestillingen av sikkerhetsfunksjonen skal være manuell.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3b655667-4852-4c38-ab8b-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/4",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/5",
                    "content": "(5) Installasjonsbeskrivelse skal oppbevares om bord. Bruksanvisningen skal være oppslått i nærheten av ovnen.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "9e37be9c-f774-4439-ab8c-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/5",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/6",
                    "content": "(6) Ovn med tilbehør skal installeres i overensstemmelse med installasjonsbeskrivelse fra produsent.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dd6cacdb-1f4b-4613-ab8d-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/6",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/7",
                    "content": "(7) Ovn skal ha avtrekk til skorstein.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "64742ca6-9419-496a-ab8e-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/7",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/9",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p9",
            "title": "Oljefyrt ovn",
            "uid": "d22a784e-dac5-48cc-2eb2-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/1",
                    "content": "(1) Ovn skal være festet forsvarlig til dørk eller fast benk, om mulig nær fartøyets senterlinje.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b4656759-9fa2-4064-ab8f-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/2",
                    "content": "(2) Ovn uten automatisk stengning av oljetilførsel ved slukket flamme, skal ha egen oljetank på maksimalt 40 liter. Oljetank skal ikke fylles automatisk og skal plasseres i den høyde som er angitt i installasjonsbeskrivelsen.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "4df7d958-ed24-4bd6-ab90-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/3",
                    "content": "(3) Oljetank skal ha vannutskiller og plugg for avtapping av eventuelt vann, og være plassert utenfor det rom hvor ovnen er installert.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "290a7349-becb-4267-ab91-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/4",
                    "content": "(4) Oljeledningen til regulator skal ha filter for utskilling av slam og vann. Filteret skal ikke plasseres over ovnen.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6fe40baf-fb29-4b61-ab92-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/4",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/5",
                    "content": "(5) Det skal brukes rør av kopper eller likeverdig materiale mellom tank og ovn. Rørene skal festes og legges slik at luftlommer unngås.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "caad9db3-b25d-4153-ab93-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/5",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/6",
                    "content": "(6) Ovn skal ha overflomsåpninger med avløpsrør og oppsamlingsbeholder. Både ovn og eventuell flottørventil skal være tilknyttet oppsamlingsbeholderen.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "08772686-efe8-4cd8-ab94-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/6",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/7",
                    "content": "(7) Røropptak skal ikke ha mindre diameter enn ovnens avløpsstuss, og røret skal legges med minst mulig bend.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f53a6bc6-40f8-4ecc-ab95-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/7",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/8",
                    "content": "(8) Drenering av kondensvann/slam, rensing av filtre, ettersyn av brennere og andre komponenter skal gjøres i tidsintervallene som er beskrevet i bruksanvisningen.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "24757e24-83a0-4cc8-ab96-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/8",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/9",
                    "content": "(9) I rom med ovn skal det være god ventilasjon.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "61423ee6-9ac4-411a-ab97-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/9",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/10",
                    "content": "(10) På fartøy med største lengde 8 til 15 meter skal ovnen kontrolleres hos godkjent foretak innen seks måneder etter at den er installert.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f3151f05-e69f-4015-ab98-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/10",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/10",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p10",
            "title": "Installasjon mv. av oljefyrt ovn",
            "uid": "1ded06f9-5e49-4131-2eb3-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/11/ledd/1",
                    "content": "(1) Skott skal isoleres med ubrennbart materiale i henhold til vedlegg 4.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e0115db9-c1d4-40ad-ab99-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/11/ledd/2",
                    "content": "(2) Tredørk eller brennbart dekksbelegg under ovn skal beskyttes med stål eller aluminiumsplate under hele ildstedet og 15 cm foran ilegget. Er ovnen plassert på benk eller liknende, skal benken beskyttes med ubrennbart materiale.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f768feac-114e-4a65-ab9a-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/11",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p11",
            "title": "Isolasjon av ildsteder mv.",
            "uid": "0b966b1a-e73c-4425-2eb4-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/1",
                    "content": "(1) Røykopptak og eksosrør skal bestå av minst 3 mm tykke stålplater og festes forsvarlig. Røykopptaksrør skal føres minst 1,3 m over dekk.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "d8cb5e94-58b9-49e7-ab9b-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/2",
                    "content": "(2) Stenullskåler med minst 6 cm tykkelse skal plasseres mellom røykopptak og brennbart materiale. Mellom tetningsplater av metall og brennbart materiale skal det isoleres med ubrennbart materiale. Alternativt kan et rør med minst 6 cm større diameter enn røykopptaksrøret monteres utenpå dette, slik at det blir vertikal luftstrømming mellom rørene. Mellom ytre rør og brennbart materiale isoleres med stenullskåler eller mineralullsnor med 3 cm tykkelse. Røret skal føres minst 1 m over dekk, og utløpet beskyttes med krage.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "73262758-c12d-4517-ab9c-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/3",
                    "content": "(3) Når røykopptak føres opp langs skott, skal skottet isoleres med ubrennbart materiale. Røykopptak skal ikke plasseres nærmere isolert skott enn 10 cm. Avstanden til isolert skott kan reduseres til 5 cm dersom røykopptak (rør) er isolert med stenullskåler eller mineralullsnor av minst 2 cm tykkelse.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "c9374caa-607a-46e5-ab9d-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/4",
                    "content": "(4) Eksosmanifold som ikke er vannavkjølt, og deler av eksosrør som kan forårsake antennelse, skal isoleres slik at oljen ikke kan trenge gjennom. Der gassene er vannavkjølt, kan andre arrangementer godtas. Eksosrør skal ikke være nærmere brennbart materiale enn 2 cm.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "2f95c609-223b-4360-ab9e-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/4",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/5",
                    "content": "(5) Oljeledninger skal legges lengst mulig bort fra eksosrør og varme maskindeler.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "4f15ecc7-78ed-4f21-ab9f-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/5",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/12",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p12",
            "title": "Røykopptak og eksosrør",
            "uid": "0a4f3e9e-f487-4110-2eb5-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/13/ledd/1",
                    "content": "Med ubrennbart materiale menes et materiale som ved prøving og vurdering i henhold til MSC.61(67) (FTP-koden) tilfredsstiller kravene til klassifisering av materialer som ubrennbare. Isolasjonen skal om nødvendig, for å bevare den brannisolerende effekten, beslås med tynnplate av galvanisert stål eller aluminium.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a11d1234-6697-4452-aba0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/13/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/13",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p13",
            "title": "Isolering med ubrennbart materiale",
            "uid": "805d1d8b-c7ad-4a2f-2eb6-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/13",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/1",
                    "content": "(1) Maskinrom i trefartøy skal ha dørk av stål eller aluminiumsplate. Maskinrom skal isoleres med ubrennbart materiale eller ha et godkjent brannslokningsanlegg.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1d9db827-bf40-40da-aba1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/2",
                    "content": "(2) Casing av tre, bjelker og underside av dekk og skott i for- og akterkant skal isoleres med ubrennbart materiale i maskinrom uten garnering.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "753ee608-be05-4a85-aba2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/3",
                    "content": "(3) Treverk skal isoleres med ubrennbart materiale ned til underkant av dørk i maskinrom med garnering. Dersom den øvrige isolasjon slutter tett inntil og rundt brenselsoljetanken kan isolasjonen bak tanken sløyfes.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "59d7f22e-c6b9-4565-aba3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/4",
                    "content": "(4) Brennbart materiale som utsettes for varme fra eksosmanifolder, eksosrør etc., i fartøy hvor motoren ikke er i et eget rom, skal isoleres med ubrennbart materiale. Brukes det motorkassedeksel, skal denne isoleres innvendig og beslås med galvanisert stål- eller aluminiumsplate.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "bc0d703c-bc0e-4e45-aba4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/4",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/14",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p14",
            "title": "Isolasjon av maskinrom på trefartøy",
            "uid": "144a0528-a8a4-47bd-2eb7-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/1",
                    "content": "(1) Fartøy med største lengde mellom 10,67 og 15 meter skal ha brannslokningsanlegg. Når det er personer om bord skal brannslukkingsanlegget bare kunne utløses manuelt.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "2f4841d3-be1d-423d-aba5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/2",
                    "content": "(2) Slokningsmiddel skal være av godkjent type. Mengden slokningsmiddel fastsettes i hvert enkelt tilfelle avhengig av maskinrommets størrelse.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a5e7c230-3408-4a11-aba6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/3",
                    "content": "(3) Slokningsanlegget skal bare kunne utløses utenfor maskinrommet. Utløserutstyret skal være tydelig merket, utstyrt med bruksinstruksjon og beskyttet mot utilsiktet utløsning.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6b31cd3b-2db7-4b1f-aba7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/4",
                    "content": "(4) Fartøy med største lengde mindre enn 10,67 meter bygget etter 1. januar 1992 kan alternativt være utstyrt med brannslokningsanlegg i samsvar med retningslinjer fastsatt i kapittel Y14 i Nordisk Båt Standard (1990).",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1d60edee-7638-4d9e-aba8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/4",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/5",
                    "content": "(5) CO -beholdere og andre beholdere for slokningsgass som kan medføre fare ved lekkasje, med tilhørende utløsningsanordning, skal være plassert i eget rom/skap utenfor maskinrom. Det skal være gasstette skott til tilstøtende rom og inngang fra åpent dekk. Et alarmsignal skal automatisk tre i funksjon når CO -rommet/skapet åpnes. Man må forsikre seg om at ingen personer er tilstede i motorrom før CO -gassen utløses. Rommet/skapet for utløsning av CO skal ha ventilasjon til fri luft.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "ca3c84f9-fbe0-49f4-aba9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/5",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/15",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p15",
            "title": "Brannslokningsanlegg i maskinrom",
            "uid": "29d96b61-9e1a-4808-2eb8-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/16/ledd/1",
                    "content": "(1) Fartøy mellom største lengde 10,67 og 15 meter, uavhengig av byggeår, skal ha brannoppdagelsesanlegg og brannalarmanlegg for maskinrom og røykvarslingsanlegg for lugarene i samsvar med vedlegg 5.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "ae3ffe1a-a70d-4a23-abaa-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/16/ledd/2",
                    "content": "(2) Fartøy mellom største lengde under 10,67 meter skal være utstyrt med minst én røyk- og én varmedetektor i maskinrom, minst én røykdetektor i oppholdsrom, og minst én røykdetektor i styrehus.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dccbfdd0-87e7-4f25-abab-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/16",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p16",
            "title": "Brannoppdagelses- og alarmanlegg",
            "uid": "c7d0bac4-6bbc-44da-2eb9-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/1",
                    "content": "(1) Alle fartøy, uavhengig av byggeår, skal ha minst to godkjente brannslokningsapparat på minst 6 kg. Minst ett godkjent brannslokningsapparat skal plasseres på egnet sted utenfor maskinrommet og minst ett godkjent brannslokningsapparat skal plasseres i innredningen. For fartøy uten styrehus eller innredning er det tilstrekkelig med ett brannslokningsapparat.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "90ebc702-2417-4a8a-abac-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/2",
                    "content": "(2) Brannslukningsapparater med slokningsmiddel under trykk skal ikke plasseres i lugarer. Brannslukningsapparater som kan bli utsatt for frost, skal være frostsikre.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "ef1a9712-2578-45c7-abad-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/3",
                    "content": "(3) Det skal være minst en reserveladning til hvert apparat. Apparatenes antall skal økes med 50prosent om det er av en type som ikke kan lades opp ombord.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "40f62375-4654-4916-abae-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/4",
                    "content": "(4) Brannslokningsapparater skal årlig kontrolleres i henhold til NS3910. Datoen for kontrollen skal påføres apparatet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6200f82d-07fe-4eab-abaf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/4",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/17",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p17",
            "title": "Brannslokningsapparater",
            "uid": "6e979af9-50d0-40c9-2eba-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/18/ledd/1",
                    "content": "Fartøyets maskinrom skal ha minst to ventilatorer som kan stenges fra dekk. Lugarer skal ha minst to ventilatorer med diameter på minst 8 cm.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "7848ccfc-dbb9-4ae7-abb0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/18/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/18",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p18",
            "title": "Ventilasjonssystemer",
            "uid": "600173c4-5eee-4e9d-2ebb-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/18",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/19/ledd/1",
                    "content": "Materialer, lakk, maling mv. fremstilt på nitrocellulosebasis eller annen lett antennelig basis, tillates ikke benyttet noe sted om bord.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "c4de1a77-4bd7-4ab3-abb1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/19/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/19",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p19",
            "title": "Materialer m.m.",
            "uid": "1e5e45fd-d3af-4f26-2ebc-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/19",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/1",
                    "content": "(1) Brennolje skal oppbevares på tanker av stål eller likeverdig materiale.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e78ee235-0291-4510-abb2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/2",
                    "content": "(2) Avløp fra brennoljetank skal være utstyrt med avstengningsventil eller kran direkte på tanken, stengbar fra dekk. Prøvekraner og kraner for oljestandsglass skal være av selvlukkende type. Tanken skal være utstyrt med spillbrett. På dekket fartøy med maskinrom skal påfyllingsrør og avluftningsrør være ført gjennom dekk ut til fri luft.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dbb91a7d-5a2a-46f6-abb3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/3",
                    "content": "(3) Dersom ekstra brennstoff eller andre brennbare væsker ikke kan anbringes på åpent dekk, skal de oppbevares i egnede beholdere i et godt ventilert rom/skap med dør kun til åpent dekk og uten elektriske eller andre tennkilder.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "0faa7c98-b9c6-443b-abb4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/3",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/20",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p20",
            "title": "Oppbevaring av brennolje og andre brennbare væsker",
            "uid": "09ce7529-c04e-4ec6-2ebd-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/21/ledd/1",
                    "content": "(1) Sjøvannsledninger, lenseledninger, rør som fører olje, og andre rørledninger nødvendige for skipets sikkerhet, skal være av ubrennbart materiale. Korte fleksible rørforbindelser av et materiale som ikke lett gjøres ubrukbart av varme kan godtas på\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/21/ledd/1/liste/a",
                            "content": "sjøvannsledninger,",
                            "uid": "60029919-8e21-4837-583c-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/21/ledd/1/liste/b",
                            "content": "korte fleksible rørforbindelser på rør som fører olje når det er nødvendig på grunn av vibrasjoner.",
                            "uid": "f57ab09d-e8a4-48cd-583d-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1/subpart/2",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "d06e0d82-f2a2-42e3-abb5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/21/ledd/2",
                    "content": "(2) Spygatt, sanitære avløp eller andre avløp nær vannlinjen hvor svikt i materialet som følge av brann kan forårsake innstrømning av vann skal være av oljebestandige og armerte materialer som ikke lett skades av varme.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "970b9667-eb68-4933-abb6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/21",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p21",
            "title": "Materialer i rørledninger mv.",
            "uid": "50e5820e-115f-4249-2ebe-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/22/ledd/1",
                    "content": "(1) Fartøy bygget etter 1. januar 1992 skal oppfylle kravene i Nordisk Båt Standard (1990)\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/a",
                            "content": "Y6 om lensesystemer,",
                            "uid": "39018ebd-7ec7-4581-583e-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/b",
                            "content": "Y9 om brennoljesystemer,",
                            "uid": "b1ce8f23-821a-4ed2-583f-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/2",
                            "language": "nb"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/c",
                            "content": "Y8 om motorinstallasjon, og",
                            "uid": "49faf21c-d8db-4156-5840-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/3",
                            "language": "nb"
                        },
                        {
                            "number": "d)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/d",
                            "content": "Y7 og Y10 om ror og propellarrangement.",
                            "uid": "a4fb155f-da27-4292-5841-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/4",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "343dfa13-16c5-47f3-abb7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/22/ledd/2",
                    "content": "(2) Fartøy bygget før 1. januar 1992 skal så langt det er mulig oppfylle kravene i Nordisk Båt Standard (1990) kapittel Y6 om lensesystemer.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "681c8e81-c95f-4632-abb8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/2",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/22",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p22",
            "title": "Maskineri og rørsystemer",
            "uid": "66488301-c02f-4e70-2ebf-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/1",
                    "content": "(1) Fartøy med største lengde 6 til 15 meter bygget etter 1. januar 1992 med elektriske anlegg med spenning inntil 50 V skal oppfylle kravene i Nordisk Båt Standard (1990) Y11 om elektriske anlegg.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "ab30a7a7-1f1c-4005-abb9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/2",
                    "content": "(2) Fartøy med største lengde 6 til 15 meter bygget før 1. januar 1992 med elektriske anlegg med spenning inntil 50 V skal være i henhold til regelverket som gjaldt ved byggetidspunktet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1d22574f-1398-4541-abba-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/3",
                    "content": "(3) Fartøy med største lengde 6 til 15 meter bygget mellom 1. januar 1992 og 2002 med elektrisk anlegg med spenning over 50 V skal tilfredsstille kravene fastsatt i den nå opphevede forskrift 1. mars 1990 nr. 125 for elektriske anlegg - Maritime installasjoner.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "9e6a83ec-8645-4565-abbb-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/4",
                    "content": "(4) Fartøy med største lengde 6 til 15 meter bygget etter 1. januar 2002 med elektrisk anlegg med spenning over 50 V skal tilfredsstille kravene fastsatt i forskrift 4. desember 2001 nr. 1450 om maritime elektriske anlegg utgitt av Direktoratet for samfunnssikkerhet og beredskap.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "33681175-36d1-400c-abbc-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/4",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/23",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p23",
            "title": "Elektriske anlegg",
            "uid": "22bb6dcd-3a47-48ba-2ec0-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/1",
                    "content": "(1) Fartøy med største lengde 10,67 til 15 meter bygget etter 1. januar 1992 skal ha nødkraft som gir tilfredsstillende belysning i minst 2 timer tilstrekkelig til\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/a",
                            "content": "belysning i område med redningsmidler og utsetningsmateriell,",
                            "uid": "d10e5f98-3062-4403-5842-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/b",
                            "content": "belysning i ganger, trapper og utganger til redningsmidlene og av sjøen hvor redningsmidlene settes ut,",
                            "uid": "db9bf422-2f02-42fc-5843-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/2",
                            "language": "nb"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/c",
                            "content": "nødvendige navigasjonslys, og",
                            "uid": "471f6ff0-a91c-48d1-5844-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/3",
                            "language": "nb"
                        },
                        {
                            "number": "d)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/d",
                            "content": "pålagt alarmsystem.",
                            "uid": "4e682852-71de-4f21-5845-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/4",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "55c955fb-9892-400a-abbd-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/2",
                    "content": "(2) Nødkraften skal komme fra en av følgende to kilder\n",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/2/liste/a",
                            "content": "akkumulatorbatteri som kan tåle belastningen etter første ledd uten oppladning eller for stort spenningsfall og som automatisk kobles til nødstrømtavla når hovedkraften svikter, eller",
                            "uid": "02c746c5-7476-44d0-5846-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2/subpart/1",
                            "language": "nb"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/2/liste/b",
                            "content": "en generator drevet av en passende kraftmaskin med selvstendig brenselforsyning, en hensiktsmessig startanordning og drevet med brensel med flammepunkt på 43 °C (110 °F) eller mer.",
                            "uid": "ea1524a6-9326-47fc-5847-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2/subpart/2",
                            "language": "nb"
                        }
                    ],
                    "sentences": [],
                    "uid": "95c7e4ee-8372-4f66-abbe-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/3",
                    "content": "(3) Hele installasjonen skal fungere selv om skipet har 22,5 grader slagside eller skipets trim er 10 grader.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dbca8021-448f-45c0-abbf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/3",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/4",
                    "content": "(4) Tavler for hovedkraft og nødkraft skal være tydelig merket og så langt som mulig plasseres slik at de ikke kan utsettes for vann eller ild. Nødkraftkilden skal om mulig plasseres over dekk. Plasseres nødkraftkilden i maskinrommet, skal den plasseres over dørk og på et godt ventilert sted.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "89567892-f55a-4d55-abc0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/4",
                    "language": "nb"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/5",
                    "content": "(5) Nødkraften og nødbelysningen i fartøy bygget før 1. januar 1992 skal være i henhold til regelverket som gjaldt ved byggetidspunktet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "279283a7-4e0e-4ebd-abc1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/5",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/24",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p24",
            "title": "Nødkraftkilde og nødlys, mv.",
            "uid": "426b1136-5eab-4299-2ec1-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24",
            "language": "nb"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/25/ledd/1",
                    "content": "Fartøy som er bygget etter Nordisk Båt Standard (1990) anses å tilfredsstille bestemmelsene i § 18, § 19 og § 20. Som 1. januar 2017 eller senere bygges om til å bruke drivstoff med flammepunkt under 60 °C.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3b33db58-f9ed-4556-abc2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/25/part/1",
                    "language": "nb"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/25",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p25",
            "title": "Likeverdige løsninger",
            "uid": "17197219-b237-4bbc-2ec2-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/25",
            "language": "nb"
        }
    ],
    "referenceId": "/kapittel/3",
    "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3",
    "title": "Brann, maskineri og elektro",
    "uid": "d39c88e3-891e-4d8e-81f9-08d8cf5768ee",
    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3",
    "language": "nb"
}

# %% [markdown]
# # transform_chapter_from_text_service_to_spacy_format

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import transform_chapter_from_text_service_to_spacy_format

importlib.reload(transform_text_service_input_to_spacy_format)

################
################

forward_text_transformed_to_spacy_format = transform_chapter_from_text_service_to_spacy_format(text_service_chapter_input)

print(forward_text_transformed_to_spacy_format)
# Out:
# [{'text': '(1) Dette kapittelet gjelder for fartøy bygget etter 2. januar 1988.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1'}, {'text': '(2) Fartøy som er bygget før 2. januar 1988 skal være bygget og utrustet etter reglene som gjaldt da fartøyet ble bygget, med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/2'}, {'text': '(3) Når et fartøy forandres eller ombygges i vesentlig omfang, skal fartøyet oppfylle kravene til nytt fartøy.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/3'}, {'text': '(1) Fartøy bygget etter 1. januar 1992 skal brannsikres konstruksjonsmessig i henhold til kapittel Y14 i Nordisk Båt Standard (1990), med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/1'}, {'text': '(2) Fartøy som er bygget før 1. januar 1992 skal brannsikres konstruksjonsmessig etter reglene som gjaldt da fartøyet ble bygget.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/2'}, {'text': '(3) Uavhengig av fartøyets byggedato skal gassfyrte anlegg skal tilfredsstille forskrift 20. oktober 1983 nr. 1580 om sikringstiltak for gassfyrte anlegg m.m. som bruker propan eller andre lette kullvannstoffer anvendt ombord på fartøy.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/3'}, {'text': '(1) Ovner med elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis\n', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1'}, {'text': 'ovnen overopphetes (maksimum 400 °C i røykgass),', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/1'}, {'text': 'flammen slukker,', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/2'}, {'text': 'det oppstår svikt i lufttilførsel eller kraftforsyning.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/3'}, {'text': '(2) Ovner uten elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis\n', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2'}, {'text': 'ovnen overopphetes (maksimum 400 °C i røykgass),', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/1'}, {'text': 'flammen slukker.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/2'}, {'text': '(3) Ovner med dryppregulering (stillkran med seglass), trenger ikke automatisk stengning av oljetilførsel når flammen slukker ved at oljeforbruket er begrenset av en oljestillerventil. Maksimalt tillatt høydeforskjell mellom oljetank og stillkran skal fremgå av installasjonsbeskrivelsen. Oljetrykksreduksjonsventil skal monteres når en tilfredsstillende oljeregulering ikke oppnås på grunn av trykkvariasjoner. Overflomssystemet skal kunne motta hele tankens volum.', 'ents': [], 'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/3'}, {'text': '(4) Tilbakestillingen av sikke ...

# %% [markdown]
# # analyse text

# %%
options = {"colors": {"FLASHPOINT": "darksalmon", "TEMPERATURE": "darkorchid", "TEMPERATURE_PREFIX": "aquamarine", "TEMPERATURE_SUFFIX": "chocolate"}}

# %%
#
# Display all spacy lines, with and without pattern match.
#

#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import spacy_matching_rule_identify_FLASHPOINT_no

from spacy_matching_rule_identify_FLASHPOINT_no import identify_FLASHPOINT_in_norwegian_spacy_lines

importlib.reload(spacy_matching_rule_identify_FLASHPOINT_no)

################
################

forward_result_with_date_in_norwegian = identify_FLASHPOINT_in_norwegian_spacy_lines(forward_text_transformed_to_spacy_format)

# display result with spacy styling
from spacy import displacy
displacy.render(forward_result_with_date_in_norwegian, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Dette kapittelet gjelder for fartøy bygget etter 2. januar 1988.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Fartøy som er bygget før 2. januar 1988 skal være bygget og utrustet etter reglene som gjaldt da fartøyet ble bygget, med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Når et fartøy forandres eller ombygges i vesentlig omfang, skal fartøyet oppfylle kravene til nytt fartøy.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Fartøy bygget etter 1. januar 1992 skal brannsikres konstruksjonsmessig i henhold til kapittel Y14 i Nordisk Båt Standard (1990), med mindre annet fremgår av de enkelte bestemmelsene i dette kapittelet.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Fartøy som er bygget før 1. januar 1992 skal brannsikres konstruksjonsmessig etter reglene som gjaldt da fartøyet ble bygget.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Uavhengig av fartøyets byggedato skal gassfyrte anlegg skal tilfredsstille forskrift 20. oktober 1983 nr. 1580 om sikringstiltak for gassfyrte anlegg m.m. som bruker propan eller andre lette kullvannstoffer anvendt ombord på fartøy.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Ovner med elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis</br></div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ovnen overopphetes (maksimum
# <mark class="entity" style="background: darkorchid; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400 °C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE</span>
# </mark>
#  i røykgass),</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">flammen slukker,</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">det oppstår svikt i lufttilførsel eller kraftforsyning.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Ovner uten elektrisk krafttilførsel, skal ha en oljetilførsel som stenges automatisk hvis</br></div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ovnen overopphetes (maksimum
# <mark class="entity" style="background: darkorchid; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400 °C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE</span>
# </mark>
#  i røykgass),</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">flammen slukker.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Ovner med dryppregulering (stillkran med seglass), trenger ikke automatisk stengning av oljetilførsel når flammen slukker ved at oljeforbruket er begrenset av en oljestillerventil. Maksimalt tillatt høydeforskjell mellom oljetank og stillkran skal fremgå av installasjonsbeskrivelsen. Oljetrykksreduksjonsventil skal monteres når en tilfredsstillende oljeregulering ikke oppnås på grunn av trykkvariasjoner. Overflomssystemet skal kunne motta hele tankens volum.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/4</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(4) Tilbakestillingen av sikkerhetsfunksjonen skal være manuell.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/5</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(5) Installasjonsbeskrivelse skal oppbevares om bord. Bruksanvisningen skal være oppslått i nærheten av ovnen.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/6</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(6) Ovn med tilbehør skal installeres i overensstemmelse med installasjonsbeskrivelse fra produsent.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/7</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(7) Ovn skal ha avtrekk til skorstein.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) Ovn skal være festet forsvarlig til dørk eller fast benk, om mulig nær fartøyets senterlinje.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(2) Ovn uten automatisk stengning av oljetilførsel ved slukket flamme, skal ha egen oljetank på maksimalt 40 liter. Oljetank skal ikke fylles automatisk og skal plasseres i den høyde som er angitt i installasjonsbeskrivelsen.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(3) Oljetank skal ha vannutskiller og plugg for avtapping av eventuelt vann, og være plassert utenfor det rom hvor ovnen er installert.</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/4</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(4) Oljeledningen t

# %% [markdown]
# # We only need the spacy lines with identified 'WATER_FLASHPOINT' and 'LENGTH'

# %%
forward_filtered_result_with_only_the_things_we_are_looking_for = [
    spacy_line for spacy_line in forward_result_with_date_in_norwegian if any("FLASHPOINT" == x['label'] for x in spacy_line['ents'])
    ]

#print(forward_filtered_result_with_only_the_things_we_are_looking_for)

# display result with spacy styling
from spacy import displacy
displacy.render(forward_filtered_result_with_only_the_things_we_are_looking_for, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2/subpart/2</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">en generator drevet av en passende kraftmaskin med selvstendig brenselforsyning, en hensiktsmessig startanordning og drevet med brensel med
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     flammepunkt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLASHPOINT</span>
# </mark>
#  på
# <mark class="entity" style="background: darkorchid; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     43 °C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE</span>
# </mark>
#  (110 °F)
# <mark class="entity" style="background: chocolate; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eller mer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE_SUFFIX</span>
# </mark>
# .</div>
#
# <h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/25/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Fartøy som er bygget etter Nordisk Båt Standard (1990) anses å tilfredsstille bestemmelsene i § 18, § 19 og § 20. Som 1. januar 2017 eller senere bygges om til å bruke drivstoff med
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     flammepunkt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLASHPOINT</span>
# </mark>
#
# <mark class="entity" style="background: aquamarine; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     under
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE_PREFIX</span>
# </mark>
#
# <mark class="entity" style="background: darkorchid; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60 °C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEMPERATURE</span>
# </mark>
# .</div></span>

# %% [markdown]
# # We now know that every line in filtered list have what we look for

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import get_data_from_text_service_item_url

importlib.reload(transform_text_service_input_to_spacy_format)

import spacy
from spacy.lang.en import English

####
nlp = English()
forward_result = []
###

for line in forward_filtered_result_with_only_the_things_we_are_looking_for:

    # Get NLP data from line
    text_service_url = line['title']
    text = line['text']
    ents = line['ents'] # discovered enteties in the line
    last_index_number_of_ents = len(ents)-1
    doc = nlp(text)

    # Get metadata from URL
    result_text_service_url = get_data_from_text_service_item_url(text_service_url)
    metadata_from_url = {}
    if "regulation_year" in result_text_service_url:
        metadata_from_url['regulation_year'] = result_text_service_url['regulation_year']
    if "regulation_month" in result_text_service_url:
        metadata_from_url['regulation_month'] = result_text_service_url['regulation_month']
    if "regulation_day" in result_text_service_url:
        metadata_from_url['regulation_day'] = result_text_service_url['regulation_day']
    if "regulation_id" in result_text_service_url:
        metadata_from_url['regulation_id'] = result_text_service_url['regulation_id']
    if "chapter_number" in result_text_service_url:
        metadata_from_url['chapter_number'] = result_text_service_url['chapter_number']
    if "section_number" in result_text_service_url:
        metadata_from_url['section_number'] = result_text_service_url['section_number']
    if "part_number" in result_text_service_url:
        metadata_from_url['part_number'] = result_text_service_url['part_number']
    if "sub_part_number" in result_text_service_url:
        metadata_from_url['sub_part_number'] = result_text_service_url['sub_part_number']

    # For each ent in line
    ents_count = len(ents)
    for ent_index_number, ent in enumerate(ents):

        ent_count_number = ent_index_number + 1

        ent_label = ent['label']
        ent_start = ent['start']
        ent_end = ent['end']

        ent_text = text[ent_start:ent_end] # same as: doc[ent_token_span.start:ent_token_span.end]
        ent_doc = nlp(ent_text)
        words_in_doc_count = len(ent_doc)

        ent_token_span = doc.char_span(ent_start,ent_end)
        ent_token_span_start = ent_token_span.start
        ent_token_span_end = ent_token_span.end
        
        #print(ent_text + " - " + ent_label + " (" + str(ent_token_span_start) + ":" + str(ent_token_span_end) + ")")

        #
        # Statment concluder
        #

        if (ent_label == "TEMPERATURE" and
            ent_index_number > 0): # TEMPERATURE is never the first ent

            prev_1_ent_index_number = ent_index_number - 1
            prev_1_ent = ents[prev_1_ent_index_number]

            if prev_1_ent['label'] == "FLASHPOINT":

                detection_with_url_metadata = dict(metadata_from_url)
                detection_with_url_metadata["flashpoint_value_1"] = ent_doc[0].text
                detection_with_url_metadata["flashpoint_value_1_measurement"] = "celsius"

                # do we have a suffix to add?
                ent_count_number_of_next_ent = ent_count_number + 1
                if ents_count >= ent_count_number_of_next_ent:
                    next_1_ent_index_number = ent_index_number + 1
                    next_1_ent = ents[next_1_ent_index_number]
                    if next_1_ent['label'] == "TEMPERATURE_SUFFIX":
                        next_1_ent_text = text[next_1_ent['start']:next_1_ent['end']]
                        detection_with_url_metadata["flashpoint_value_1_suffix"] = next_1_ent_text

                forward_result.append(detection_with_url_metadata)

            elif (prev_1_ent['label'] == "TEMPERATURE_PREFIX" and
                ent_index_number > 1):

                prev_2_ent_index_number = ent_index_number - 2
                prev_2_ent = ents[prev_2_ent_index_number]

                if prev_2_ent['label'] == "FLASHPOINT":

                    detection_with_url_metadata = dict(metadata_from_url)
                    detection_with_url_metadata["flashpoint_value_1"] = ent_doc[0].text
                    detection_with_url_metadata["flashpoint_value_1_measurement"] = "celsius"
                    prev_1_ent_text = text[prev_1_ent['start']:prev_1_ent['end']]
                    detection_with_url_metadata["flashpoint_value_1_prefix"] = prev_1_ent_text

                    # do we have a suffix to add?
                    ent_count_number_of_next_ent = ent_count_number + 1
                    if ents_count >= ent_count_number_of_next_ent:
                        next_1_ent_index_number = ent_index_number + 1
                        next_1_ent = ents[next_1_ent_index_number]
                        if next_1_ent['label'] == "TEMPERATURE_SUFFIX":
                            next_1_ent_text = text[next_1_ent['start']:next_1_ent['end']]
                            detection_with_url_metadata["flashpoint_value_1_suffix"] = next_1_ent_text

                    forward_result.append(detection_with_url_metadata)

forward_result
# Out:
# [{'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '24',
#   'part_number': '2',
#   'sub_part_number': '2',
#   'flashpoint_value_1': '43',
#   'flashpoint_value_1_measurement': 'celsius',
#   'flashpoint_value_1_suffix': 'eller mer'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '25',
#   'part_number': '1',
#   'flashpoint_value_1': '60',
#   'flashpoint_value_1_measurement': 'celsius',
#   'flashpoint_value_1_prefix': 'under'}]

# %% [markdown]
# # Create API responce

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import api_controller_identify_FLASHPOINT_in_text_service_norwegian_chapter

from api_controller_identify_FLASHPOINT_in_text_service_norwegian_chapter import create_api_response_for_post_identify_FLASHPOINT_in_text_service_norwegian_chapter

importlib.reload(api_controller_identify_FLASHPOINT_in_text_service_norwegian_chapter)

#####

create_api_response_for_post_identify_FLASHPOINT_in_text_service_norwegian_chapter(forward_filtered_result_with_only_the_things_we_are_looking_for)
# Out:
# [{'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '24',
#   'part_number': '2',
#   'sub_part_number': '2',
#   'flashpoint_value_1': '43',
#   'flashpoint_value_1_measurement': 'celsius',
#   'flashpoint_value_1_suffix': 'eller mer'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '25',
#   'part_number': '1',
#   'flashpoint_value_1': '60',
#   'flashpoint_value_1_measurement': 'celsius',
#   'flashpoint_value_1_prefix': 'under'}]
