# %% [markdown]
# # Initialize

# %%
# !pip install -U spacy==2.3.5

# %%
import spacy
print(spacy.__version__)
# Out:
# 2.3.5

# %%
# Had to run this to make something below work.
# This is a donwgrade of numpy to a version without a bug.
# This is a temp solution until a new version of numpy has solved the bug.
# !pip install numpy==1.19.3 --user

# %% [markdown]
# # api input

# %%
text_service_chapter_input = {
    "sections": [
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/1",
                    "content": "(1) This chapter applies to vessels constructed after 2 January 1988.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e103da4d-bb8a-431a-aca8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/2",
                    "content": "(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1f4e4c3e-b2c5-4736-aca9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/7/ledd/3",
                    "content": "(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new vessel.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e2787dce-9a8a-45f8-acaa-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/3",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/7",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p7",
            "title": "Scope of application of this chapter",
            "uid": "6d345797-c77e-4458-2f19-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/1",
                    "content": "(1) Vessels constructed after 1 January 1992 shall have structural fire protection in accordance with chapter C14 of Nordic Boat Standard (1990), unless otherwise provided by the individual provisions of this chapter.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8b18309e-0d79-496a-acab-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/2",
                    "content": "(2) Vessels constructed before 1 January 1992 shall have structural fire protection in accordance with the rules applicable at the time of construction of the vessel.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f7e326d4-bb6c-4cd7-acac-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/8/ledd/3",
                    "content": "(3) Irrespective of the year of construction of the vessel, gasfired installations shall satisfy the requirements of Regulations of 20 October 1983 No. 1580 on safety precautions for gasfired installations, etc. operating on propane or other liquefied hydrocarbon gases used on board vessels.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3207aba7-90d1-4d15-acad-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8/part/3",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/8",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p8",
            "title": "Fire safety",
            "uid": "ae663a17-7a91-4507-2f1a-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/8",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/1",
                    "content": "\n\t\t\t\t\t(1) Stoves with electric power supply shall have an oil supply which shuts off automatically if:\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/a",
                            "content": "the stove is over-heated (maximum 400°C in smoke gas);",
                            "uid": "6b8057e3-f2da-4adc-58e7-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/b",
                            "content": "the flame goes out;",
                            "uid": "70dd6b65-ee45-474f-58e8-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/2",
                            "language": "en"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/1/liste/c",
                            "content": "a failure occurs in the supply of air or power.",
                            "uid": "63f1f72f-5746-401f-58e9-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1/subpart/3",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "09d1cd36-8a9c-44e7-acae-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/2",
                    "content": "\n\t\t\t\t\t(2) Stoves without electric power supply shall have an oil supply which shuts off automatically if\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/2/liste/a",
                            "content": "the stove is over-heated (maximum 400°C in smoke gas);",
                            "uid": "bd4eeb2b-9910-4371-58ea-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/9/ledd/2/liste/b",
                            "content": "the flame goes out.",
                            "uid": "dc0e294a-fa5c-40b4-58eb-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2/subpart/2",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "9cf1b2f5-47a5-4aec-acaf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/3",
                    "content": "(3) Drip regulation stoves (regulation valve with observation hole) need not have automatic shutoff of the oil supply if the flame will go out due to the oil consumption being limited by an oil regulation valve. The installation instructions shall indicate the maximum permitted difference in height between the oil tank and the regulation valve. An oil pressure reduction valve shall be fitted if satisfactory regulation of the oil supply cannot be achieved through pressure variations. The overflow system shall be capable of receiving the full volume of the tank.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "bbbcaf08-fb9b-40ca-acb0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/4",
                    "content": "(4) The resetting of the safety function shall be manual.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b7c36c07-e829-4e50-acb1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/4",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/5",
                    "content": "(5) The installation instructions shall be kept on board. The instructions for use shall be posted near the stove.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "38366e91-7cfc-4a32-acb2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/5",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/6",
                    "content": "(6) Stoves with accessories shall be installed in accordance with the installation instructions from the manufacturer.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "75d7c8ac-d09a-4665-acb3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/6",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/9/ledd/7",
                    "content": "(7) Stoves shall have smoke outlet to uptake.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e7901931-f55d-4e97-acb4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9/part/7",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/9",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p9",
            "title": "Oil-fired stoves",
            "uid": "066f6338-2dc2-49c9-2f1b-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/9",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/1",
                    "content": "(1) Stoves shall be securely fixed to the floor or to a fixed bench, if possible near the centre line of the vessel.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a98701ca-6f1e-4911-acb5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/2",
                    "content": "(2) Stoves without automatic shutoff of oil supply in the event of the flame going out, shall be provided with a separate oil tank of maximum 40 litres. The oil tank shall not be filled automatically, and shall be placed on the height indicated in the installation instructions.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "52edfdcf-1e03-4fa4-acb6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/3",
                    "content": "(3) The oil tank shall have a water separator and a plug for draining off possible collection of water and shall be placed outside the space where the stove is installed.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a4e3b344-7e04-4ea2-acb7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/4",
                    "content": "(4) The oil pipe to the regulator shall have a filter for the separation of mud and water. The filter shall not be fitted above the stove.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dd61a4ea-153d-41f7-acb8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/4",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/5",
                    "content": "(5) Pipes made of copper or equivalent material shall be used between the tank and the stove. The pipes shall be fixed and placed so as to prevent the formation of air pockets.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "49e70dbc-c2b7-4413-acb9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/5",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/6",
                    "content": "(6) Stoves shall have overflow openings with drain pipes and collection tank. Both the stove and the float valve, if used, shall be connected to the collection tank.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f4553718-3d0d-47d6-acba-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/6",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/7",
                    "content": "(7) Smoke uptake pipes shall have a diameter which is not less than the smoke outlet of the stove, and the piping shall be made as straight as possible.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f70689e3-f808-4657-acbb-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/7",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/8",
                    "content": "(8) Drainage of condensed water/mud, cleaning of filters, inspection of burners and other components shall be carried out in the time intervals stipulated in the operating instructions.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "56a41e8b-b2e3-4254-acbc-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/8",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/9",
                    "content": "(9) Spaces with a stove shall be well ventilated.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "40de9bf4-49d0-4d5e-acbd-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/9",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/10/ledd/10",
                    "content": "(10) On vessels of 8 to 15 metres in overall length the stove shall be inspected by an approved company within six months of being installed.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "0326681d-1457-41e8-acbe-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10/part/10",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/10",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p10",
            "title": "Installation, etc. of oilfired stove",
            "uid": "e36bc58d-f781-4f1f-2f1c-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/10",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/11/ledd/1",
                    "content": "(1) Bulkheads shall be insulated with non-combustible material in accordance with Appendix 4.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "85adde8a-7250-437c-acbf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/11/ledd/2",
                    "content": "(2) Below stoves, wooden floor or combustible floor covering shall be protected by steel or aluminium sheets covering the whole floor area under the fireplace and in front of the stove at least 15 cm from the fire door. Where the stove is placed on a bench or similar, the bench shall be protected by non-combustible material.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "c4e4298c-aedf-4694-acc0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11/part/2",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/11",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p11",
            "title": "Insulation of fireplaces, etc.",
            "uid": "84b4caf3-0d5f-4076-2f1d-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/11",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/1",
                    "content": "(1) Smoke uptakes and exhaust pipes shall consist of at least 3 mm thick steel plates and shall be securely fixed. Smoke uptakes shall be carried at least 1.3 m above deck.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "434d147b-0740-4c7a-acc1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/2",
                    "content": "(2) Saucer formed rockwool sheets of at least 6 cm thickness shall be provided between smoke uptake and combustible material. Insulation in the form of non-combustible material shall be provided between metal cover plates and combustible material. Alternatively, a pipe with a diameter at least 6 cm larger than the smoke uptake pipe may be fitted outside this pipe, in order to provide vertical air circulation between the pipes. Insulation by saucer formed rockwool or mineral wool twine of at least 3 cm thickness shall be provided between the outer pipe and combustible material. The pipe shall be carried to at least 1 m above the deck, and the outlet shall be protected with a collar.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "529c1957-a75c-451e-acc2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/3",
                    "content": "(3) When smoke uptake is carried along a bulkhead, the bulkhead shall be insulated with non-combustible material. Smoke uptakes shall not be placed closer than 10 cm to insulated bulkheads. Where the smoke uptake (pipe) is insulated with saucer formed rockwool or mineral wool twine of at least 2 cm thickness, the distance to the insulated bulkhead may be reduced to 5 cm.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "cead3f52-d5c6-4b20-acc3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/4",
                    "content": "(4) Any exhaust manifold which is not watercooled, and parts of exhaust pipes which may cause ignition, shall be insulated so that oil cannot penetrate. Where gases are watercooled, other arrangements may be accepted. Exhaust pipes shall not be closer than 2 cm to combustible material.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "37641ea2-9301-4fe8-acc4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/4",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/12/ledd/5",
                    "content": "(5) Oil pipes shall be placed as far as possible away from exhaust pipes and hot engine parts.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "ad36ebde-2200-4915-acc5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12/part/5",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/12",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p12",
            "title": "Smoke uptake and exhaust pipes",
            "uid": "d979997f-d4dd-4d7d-2f1e-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/12",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/13/ledd/1",
                    "content": "Non-combustible material means a material which, when tested and evaluated in accordance with MSC.61(67) (the FTP Code), satisfies the requirements for qualifying materials as non-combustible. The insulation shall, if necessary in order to preserve the fire-insulating effect, be mounted with a sheet of galvanized steel or aluminium.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "0ed728b4-723b-479c-acc6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/13/part/1",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/13",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p13",
            "title": "Insulation with non-combustible material",
            "uid": "ed590e1d-c0e1-4c5b-2f1f-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/13",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/1",
                    "content": "(1) Machinery spaces in wooden vessels shall have floors of steel or aluminium plates. Machinery spaces shall be insulated with non-combustible material or have an approved fire-extinguishing system.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "7fb99112-31d6-49d2-acc7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/2",
                    "content": "(2) In machinery spaces without inside planking, wooden casings, beams and surfaces under deck as well as bulkheads forwards and aft in the machinery space shall be insulated with non-combustible material.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "7153a131-dc1c-4eed-acc8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/3",
                    "content": "(3) In machinery spaces with inside planking, all woodwork shall be insulated with non-combustible material down to the lower edge of the floor. No insulation is required behind fuel oil tanks if the other insulation is fitted tightly around the tank.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "472b9795-74de-4bb2-acc9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/14/ledd/4",
                    "content": "(4) In vessels where the engine is not placed in a separate compartment, all combustible material which is exposed to heat from exhaust manifolds, exhaust pipes, etc. shall be insulated with non-combustible material. When an engine cover is used, this shall be insulated on the inside and be mounted with a galvanized steel or aluminium sheet.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "d9419321-6c82-4045-acca-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14/part/4",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/14",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p14",
            "title": "Insulation of machinery spaces in wooden vessels",
            "uid": "a254395a-0008-456a-2f20-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/14",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/1",
                    "content": "(1) Vessels of 10.67 to 15 metres in overall length shall have a fire-extinguishing system. When there are persons on board, the fire-extinguishing system shall only be capable of manual release.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "3a599bfa-b0cd-431b-accb-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/2",
                    "content": "(2) Extinguishing medium shall be of an approved type. The amount of extinguishing medium is determined in each individual case depending on the size of the machinery space.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "a502ad92-f502-4617-accc-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/3",
                    "content": "(3) The fire-extinguishing system shall only be capable of being released from a position outside the machinery space. The release equipment shall be clearly marked, provided with instructions for use and protected against unintentional release.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8260ad71-31f4-4310-accd-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/4",
                    "content": "(4) Vessels of less than 10.67 metres in overall length constructed after 1 January 1992 may as an alternative be equipped with a fire-extinguishing system in accordance with guidelines laid down in chapter C14 of Nordic Boat Standard (1990).",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b9bd0220-e4c9-4521-acce-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/4",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/15/ledd/5",
                    "content": "(5) CO2 containers and other containers for extinguishing gas which could may be hazardous in the event of a leak, with appurtenant release device, shall be placed in a separate space/locker outside the machinery space. Gastight bulkheads shall be provided to adjacent spaces and entrance from open deck. An alarm signal shall be activated automatically when the CO2 space/locker is opened. It should be ensured that no persons are present in the machinery space before the CO2 gas is released. The space/locker for release of CO2 shall have ventilation to the open air.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "dbb6de6e-d80f-4794-accf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15/part/5",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/15",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p15",
            "title": "Fire-extinguishing systems in machinery spaces",
            "uid": "cc249a55-dc6a-478c-2f21-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/15",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/16/ledd/1",
                    "content": "(1) Vessels of 10.67 to 15 metres in overall length, irrespective of year of construction, shall have fire detection system and fire alarm system for machinery spaces and smoke alarm system for the cabins in accordance with Appendix 5.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "223ddca5-3902-487f-acd0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/16/ledd/2",
                    "content": "(2) Vessels of less than 10.67 meters in overall length shall be fitted with at least one smoke detector and one heat detector in machinery spaces, at least one smoke detector in recreational spaces, and at least one smoke detector in the wheelhouse.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "f10f1a18-5c2a-4862-acd1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16/part/2",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/16",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p16",
            "title": "Fire detection and alarm system",
            "uid": "b8958edb-c7aa-47a5-2f22-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/16",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/1",
                    "content": "(1) All vessels, irrespective of year of construction, shall have at least two approved fire extinguishers of at least 6 kg. At least one approved fire extinguisher shall be placed at a suitable place outside the machinery space and at least one approved fire extinguisher shall be placed in the accommodation spaces. For vessels without wheelhouse or accommodation spaces one fire extinguisher is sufficient.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6b3c226c-49cc-4aae-acd2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/1",
                    "content": "(1) Fire extinguishers with pressurised extinguishing medium shall not be placed in accommodation spaces. Fire extinguishers which may be exposed to frost shall be of a frost-proof type.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8481784f-e958-4c8f-acd3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/3",
                    "content": "(3) At least one spare charge shall be provided for each extinguisher. If the extinguisher is of a type that cannot be charged on board, the number of extinguishers shall be increased by 50 per cent.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "6fd6b557-ed96-4141-acd4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/17/ledd/4",
                    "content": "(4) Fire extinguishers shall be inspected annually in accordance with NS3910. The date of the inspection shall be marked on the extinguisher.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "2b4ae5f0-348d-46af-acd5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17/part/4",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/17",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p17",
            "title": "Fire extinguishers",
            "uid": "45478a63-61fe-482d-2f23-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/17",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/18/ledd/1",
                    "content": "The vessel's machinery space shall have at least two ventilators capable of being closed from deck. Cabins shall have at least two ventilators with a diameter of at least 8 cm.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "7b0c661e-ddaa-4994-acd6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/18/part/1",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/18",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p18",
            "title": "Ventilation systems",
            "uid": "e4fe5d9a-ae39-4d49-2f24-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/18",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/19/ledd/1",
                    "content": "Materials, varnishes, paints, etc. produced on a nitrocellulose basis or any other basis which will readily ignite are not permitted to be used anywhere on board.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "eb287197-c7a4-45ee-acd7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/19/part/1",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/19",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p19",
            "title": "Materials, etc.",
            "uid": "6e67236f-4410-4280-2f25-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/19",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/1",
                    "content": "(1) Oil fuel shall be stored in tanks of steel or equivalent material.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "62a56ae1-2668-4d01-acd8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/2",
                    "content": "(2) Outlets from oil fuel tanks shall be fitted with a closing valve or cock on the tank itself, which is capable of being closed from the deck. Test cocks and cocks for oil gauge glass shall be of a self-closing type. The tank shall be fitted with drip trays. In decked vessels with machinery space, filling pipes and airing pipes shall be carried through the deck and into open air.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8ea7081d-537f-474f-acd9-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/20/ledd/3",
                    "content": "(3) If extra fuel or other flammable liquids cannot be placed on open deck, they shall be stored in suitable containers in a well-ventilated room/locker with a door communicating only with open deck and without electrical or other sources of ignition.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b9ecc127-a54d-480c-acda-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20/part/3",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/20",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p20",
            "title": "Storage of oil fuel and other flammable liquids",
            "uid": "374527e4-785c-46e9-2f26-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/20",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/21/ledd/1",
                    "content": "\n\t\t\t\t\t(1) Seawater pipes, bilge pipes, pipes conveying oil and other pipelines required for the safety of the ship shall be made of non-combustible material. Short, flexible pipe connections made of a material which is not easily rendered ineffective by heat, may be accepted on:\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/21/ledd/1/liste/a",
                            "content": "seawater pipes;",
                            "uid": "956740fa-1ce9-4429-58ec-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/21/ledd/1/liste/b",
                            "content": "short, flexible pipe connections on pipes conveying oil, when necessitated by vibrations.",
                            "uid": "063b0203-276c-4b95-58ed-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1/subpart/2",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "49314a00-3b8e-4e6e-acdb-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/21/ledd/2",
                    "content": "(2) Where failure of the material due to fire may lead to flooding, scuppers, sanitary discharges or other outlets which are close to the waterline shall be made of oil-resistant and reinforced materials which are not easily damaged by heat.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "e0bc763d-ee77-4fe8-acdc-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21/part/2",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/21",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p21",
            "title": "Materials in pipelines, etc.",
            "uid": "c1d06294-9461-4c41-2f27-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/21",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/22/ledd/1",
                    "content": "\n\t\t\t\t\t(1) Vessels constructed after 1 January 1992 shall satisfy the requirements of Nordic Boat Standard (1990)\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/a",
                            "content": "C6 on bilge systems;",
                            "uid": "0975b581-920d-4858-58ee-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/b",
                            "content": "C9 on oil fuel systems;",
                            "uid": "301fce5e-55af-426b-58ef-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/2",
                            "language": "en"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/c",
                            "content": "C8 on engine installations; and",
                            "uid": "cc360200-a860-40d2-58f0-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/3",
                            "language": "en"
                        },
                        {
                            "number": "d)",
                            "referenceId": "/kapittel/3/paragraf/22/ledd/1/liste/d",
                            "content": "C7 and C10 on rudder and propeller arrangements.",
                            "uid": "d110c623-9150-43f5-58f1-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1/subpart/4",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "b14e3074-0bf1-4983-acdd-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/22/ledd/2",
                    "content": "(2) Vessels constructed before 1 January 1992 shall as far as possible satisfy the requirements of Nordic Boat Standard (1990 chapter C6 on bilge systems.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "9d86ee6b-bf2a-4ca1-acde-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22/part/2",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/22",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p22",
            "title": "Machinery and piping systems",
            "uid": "a72497b3-abec-433a-2f28-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/22",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/1",
                    "content": "(1) Vessels of 6 to 15 metres in overall length constructed after 1 January 1992 with electrical installations with voltages of up to 50 V shall satisfy the requirements of Nordic Boat Standard (1990) C11 on electrical installations.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "8554a2d6-5ada-4ca2-acdf-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/2",
                    "content": "(2) Vessels of 6 to 15 metres in overall length constructed before 1 January 1992 with electrical installations with voltages of up to 50 V shall be in compliance with the rules in force at the time of construction.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b4f1854d-577f-42d7-ace0-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/3",
                    "content": "(3) Vessels of 6 to 15 metres in overall length constructed between 1 January 1992 and 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in the now repealed Regulations of 1 March 1990 No. 125 for electrical installations - Maritime installations.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "2b0010a1-3a64-458f-ace1-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/23/ledd/4",
                    "content": "(4) Vessels of 6 to 15 metres in overall length constructed after 1 January 2002 with electrical installations with voltages of more than 50 V shall satisfy the requirements laid down in Regulations of 4 December 2001 No. 1450 concerning maritime electrical installations, laid down by the Norwegian Directorate for Civil Protection.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1020263c-09cb-46af-ace2-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23/part/4",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/23",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p23",
            "title": "Electrical installations",
            "uid": "a9ffa3e1-e1b0-4299-2f29-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/23",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/1",
                    "content": "\n\t\t\t\t\t(1) Vessels of 10.67 to 15 metres in overall length constructed after 1 January 1992 shall have an emergency source of power providing satisfactory lighting for at least 2 hours to:\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/a",
                            "content": "lighting in areas with life-saving appliances and launching arrangements;",
                            "uid": "3ed63742-268e-47ab-58f2-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/b",
                            "content": "lighting in alleyways, stairways and exits to the life-saving appliances and of the sea where the life-saving appliances are launched;",
                            "uid": "b32e406e-6fed-447c-58f3-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/2",
                            "language": "en"
                        },
                        {
                            "number": "c)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/c",
                            "content": "necessary navigation lights; and",
                            "uid": "ecec45eb-99b4-4fdf-58f4-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/3",
                            "language": "en"
                        },
                        {
                            "number": "d)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/1/liste/d",
                            "content": "required alarm system.",
                            "uid": "04d5feb0-2334-44a6-58f5-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1/subpart/4",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "a8f1dd79-abbb-4e5c-ace3-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/1",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/2",
                    "content": "\n\t\t\t\t\t(2) The emergency power shall be provided by one of the following two sources:\n\t\t\t\t\t",
                    "subparts": [
                        {
                            "number": "a)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/2/liste/a",
                            "content": "an accumulator battery capable of carrying the load pursuant to the first paragraph without recharging or suffering an excessive voltage drop, and which is automatically connected to the emergency switchboard when the main power fails; or",
                            "uid": "a50fae59-ed52-4439-58f6-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2/subpart/1",
                            "language": "en"
                        },
                        {
                            "number": "b)",
                            "referenceId": "/kapittel/3/paragraf/24/ledd/2/liste/b",
                            "content": "a generator driven by a suitable type of power machinery with an independent supply of fuel, appropriate starting arrangements and driven by fuel having a flashpoint of not less than 43°C (110°F).",
                            "uid": "4abfd19c-60f5-412e-58f7-08d8cf57691c",
                            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2/subpart/2",
                            "language": "en"
                        }
                    ],
                    "sentences": [],
                    "uid": "a78c5a46-d7f5-45a9-ace4-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/2",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/3",
                    "content": "(3) The entire installation shall be capable of operating even when the vessel is listed to 22.5 degrees or when the trim of the vessel is 10 degrees.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "9acafdcf-f188-4846-ace5-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/3",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/4",
                    "content": "(4) Switchboards for main power and emergency power shall be clearly marked and be placed, as far as practicable, so that they cannot be exposed to water or fire. The emergency source of power shall if possible be placed above deck. If the emergency source of power is placed in the machinery space, it shall be placed above the floor and in a well-ventilated place.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "1a1dd181-1b83-41ce-ace6-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/4",
                    "language": "en"
                },
                {
                    "referenceId": "/kapittel/3/paragraf/24/ledd/5",
                    "content": "(5) The emergency source of power and the emergency lighting on vessels constructed before 1 January 1992 shall be in accordance with the rules in force at the time of construction.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "b70cfdbb-b6eb-4400-ace7-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24/part/5",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/24",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p24",
            "title": "Emergency source of power and emergency lighting, etc.",
            "uid": "110ca500-605f-4a76-2f2a-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/24",
            "language": "en"
        },
        {
            "parts": [
                {
                    "referenceId": "/kapittel/3/paragraf/25/ledd/1",
                    "content": "Vessels constructed pursuant to Nordic Boat Standard (1990) are considered to satisfy the requirements of sections 18, 19 and 20.",
                    "subparts": [],
                    "sentences": [],
                    "uid": "cf674666-81f9-43b7-ace8-08d8cf5768ff",
                    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/25/part/1",
                    "language": "en"
                }
            ],
            "tables": [],
            "referenceId": "/kapittel/3/paragraf/25",
            "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3/p25",
            "title": "Equivalents",
            "uid": "52eebe95-45e6-438a-2f2b-08d8cf5768f1",
            "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/25",
            "language": "en"
        }
    ],
    "referenceId": "/kapittel/3",
    "referenceUrl": "https://lovdata.no/forskrift/2013-11-22-1404/k3",
    "title": "Fire, machinery and electric installations",
    "uid": "8d502743-d9de-483e-8203-08d8cf5768ee",
    "url": "https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3",
    "language": "en"
}

# %% [markdown]
# # transform_chapter_from_text_service_to_spacy_format

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import transform_chapter_from_text_service_to_spacy_format

importlib.reload(transform_text_service_input_to_spacy_format)

################
################

forward_text_transformed_to_spacy_format = transform_chapter_from_text_service_to_spacy_format(text_service_chapter_input)

#print(forward_text_transformed_to_spacy_format)
forward_text_transformed_to_spacy_format
# Out:
# [{'text': '(1) This chapter applies to vessels constructed after 2 January 1988.',
#   'ents': [],
#   'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1'},
#  {'text': '(2) Vessels constructed before 2 January 1988 shall be constructed and equipped in accordance with the rules applicable at the time of construction of the vessel, unless otherwise provided by the individual provisions of this chapter.',
#   'ents': [],
#   'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/2'},
#  {'text': '(3) When a vessel is substantially altered or modified, the vessel shall comply with the requirements for a new vessel.',
#   'ents': [],
#   'title': 'https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/3'},
# ...

# %% [markdown]
# # analyse text

# %%
options = {"colors": {"DATE": "orange", "WATER_VESSEL": "aquamarine", "CONSTRUCT": "darksalmon", "DATE_SEPARATOR": "cornflowerblue", "DATE_PREFIX": "lightgoldenrodyellow"}}

# %%
#
# Display all spacy lines, with and without pattern match.
#

#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import spacy_matching_rule_identify_build_date_en

from spacy_matching_rule_identify_build_date_en import identify_build_date_in_english_spacy_lines

importlib.reload(spacy_matching_rule_identify_build_date_en)

################
################

forward_result_with_date_in_english = identify_build_date_in_english_spacy_lines(forward_text_transformed_to_spacy_format)

# display result with spacy styling
from spacy import displacy
displacy.render(forward_result_with_date_in_english, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) This chapter applies to
# <mark class="entity" style="background: aquamarine; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vessels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WATER_VESSEL</span>
# </mark>
#
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     constructed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CONSTRUCT</span>
# </mark>
#
# ...

# %% [markdown]
# # We only need the spacy lines with identified 'WATER_VESSEL' and 'LENGTH'

# %%
forward_filtered_result_with_only_the_things_we_are_looking_for = [
    spacy_line for spacy_line in forward_result_with_date_in_english if any("WATER_VESSEL" == x['label'] for x in spacy_line['ents']) and any("CONSTRUCT" == x['label'] for x in spacy_line['ents']) and any("DATE" == x['label'] for x in spacy_line['ents'])
    ]

# display result with spacy styling
from spacy import displacy
displacy.render(forward_filtered_result_with_only_the_things_we_are_looking_for, style='ent', manual=True, options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">https://sdir-d-apim-common.azure-api.net/core-text-internal/regulation/2013/11/22/1404/chapter/3/section/7/part/1</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">(1) This chapter applies to
# <mark class="entity" style="background: aquamarine; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vessels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WATER_VESSEL</span>
# </mark>
#
# <mark class="entity" style="background: darksalmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     constructed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CONSTRUCT</span>
# </mark>
#
# ...

# %% [markdown]
# # We now know that every line in filtered list have what we look for

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import transform_text_service_input_to_spacy_format

from transform_text_service_input_to_spacy_format import get_data_from_text_service_item_url

importlib.reload(transform_text_service_input_to_spacy_format)

import spacy
from spacy.lang.en import English

####

nlp = English()

forward_result = []

###

### TEMP AREA
temp_detection_dictionary = {}
temp_check_before_reset = {}
###

for line in forward_filtered_result_with_only_the_things_we_are_looking_for:

    # new line and temp reset
    temp_detection_dictionary.clear()
    temp_check_before_reset.clear()

    # Get NLP data from line
    text_service_url = line['title']
    text = line['text']
    ents = line['ents'] # discovered enteties in the line
    last_index_number_of_ents = len(ents)-1
    doc = nlp(text)

    # Get metadata from URL
    result_text_service_url = get_data_from_text_service_item_url(text_service_url)
    metadata_from_url = {}
    if "regulation_year" in result_text_service_url:
        metadata_from_url['regulation_year'] = result_text_service_url['regulation_year']
    if "regulation_month" in result_text_service_url:
        metadata_from_url['regulation_month'] = result_text_service_url['regulation_month']
    if "regulation_day" in result_text_service_url:
        metadata_from_url['regulation_day'] = result_text_service_url['regulation_day']
    if "regulation_id" in result_text_service_url:
        metadata_from_url['regulation_id'] = result_text_service_url['regulation_id']
    if "chapter_number" in result_text_service_url:
        metadata_from_url['chapter_number'] = result_text_service_url['chapter_number']
    if "section_number" in result_text_service_url:
        metadata_from_url['section_number'] = result_text_service_url['section_number']
    if "part_number" in result_text_service_url:
        metadata_from_url['part_number'] = result_text_service_url['part_number']
    if "sub_part_number" in result_text_service_url:
        metadata_from_url['sub_part_number'] = result_text_service_url['sub_part_number']

    # For each ent in line
    for ent_index_number, ent in enumerate(ents):

        ent_label = ent['label']
        ent_start = ent['start']
        ent_end = ent['end']

        ent_text = text[ent_start:ent_end] # same as: doc[ent_token_span.start:ent_token_span.end]
        ent_doc = nlp(ent_text)
        words_in_doc_count = len(ent_doc)

        ent_token_span = doc.char_span(ent_start,ent_end)
        ent_token_span_start = ent_token_span.start
        ent_token_span_end = ent_token_span.end
        
        #print(ent_text + " - " + ent_label + " (" + str(ent_token_span_start) + ":" + str(ent_token_span_end) + ")")

        #
        # Statment builder
        #

        if ent_label == "WATER_VESSEL":
            if "START_detected" not in temp_detection_dictionary:
                temp_detection_dictionary["START_detected"] = True
            else: # restart with new term
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()
                temp_detection_dictionary["START_detected"] = True
                
        elif ent_label == "CONSTRUCT":
            if ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" not in temp_detection_dictionary):
                temp_detection_dictionary["CONSTRUCT_detected"] = True
            else: # reset
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()
                
        elif ent_label == "DATE_PREFIX":
            if ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" in temp_detection_dictionary and
                "DATE_PREFIX_value" not in temp_detection_dictionary and
                "DATE_value_1" not in temp_detection_dictionary and
                "DATE_SEPARATOR_value" not in temp_detection_dictionary and
                "DATE_value_2" not in temp_detection_dictionary):
                temp_detection_dictionary["DATE_PREFIX_value"] = ent_text
            else: # reset
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()

        elif ent_label == "DATE":
            if ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" in temp_detection_dictionary and
                "DATE_value_1" not in temp_detection_dictionary and
                "DATE_value_1_token_end" not in temp_detection_dictionary):

                temp_detection_dictionary["DATE_value_1"] = ent_text
                temp_detection_dictionary["DATE_value_1_token_end"] = ent_token_span_end

                # Extra prefix check
                #prev_word = doc[ent_token_span_start-1].text
                #if prev_word != "(":
                    #temp_detection_dictionary["DATE_value_1"] = ent_text
                    #temp_detection_dictionary["DATE_value_1_token_end"] = ent_token_span_end
                #else: # reset
                    #temp_check_before_reset = dict(temp_detection_dictionary)
                    #temp_detection_dictionary.clear()

            elif ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" in temp_detection_dictionary and
                "DATE_value_1" in temp_detection_dictionary and
                "DATE_SEPARATOR_value" in temp_detection_dictionary and
                "DATE_value_2" not in temp_detection_dictionary):
                temp_detection_dictionary['DATE_value_2'] = ent_text
                # because this is the last value in a statment:
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()
            else: # reset
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()

        elif ent_label == "DATE_SEPARATOR":
            if ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" in temp_detection_dictionary and
                "DATE_value_1" in temp_detection_dictionary and
                "DATE_value_1_token_end" in temp_detection_dictionary and
                "DATE_SEPARATOR_value" not in temp_detection_dictionary):
                # Q: Is the separator the next term after value 1?
                if temp_detection_dictionary["DATE_value_1_token_end"] == ent_token_span_start:
                    # A: Yes, this separator is the first word after value 1
                    temp_detection_dictionary["DATE_SEPARATOR_value"] = ent_text
                else: # reset
                    # A: No. Reject value and reset.
                    temp_check_before_reset = dict(temp_detection_dictionary)
                    temp_detection_dictionary.clear()
            else: # reset
                temp_check_before_reset = dict(temp_detection_dictionary)
                temp_detection_dictionary.clear()

        #
        # Statment concluder
        # Q: Do we have what we need to build a statment?
        #

        # The statment builder have restarted.
        # Check what we have for a statment before continuing.
        if len(temp_check_before_reset) > 0:
            # If we have a double value statement
            if ("START_detected" in temp_check_before_reset and
                "CONSTRUCT_detected" in temp_check_before_reset and
                "DATE_value_1" in temp_check_before_reset and
                "DATE_SEPARATOR_value" in temp_check_before_reset and
                "DATE_value_2" in temp_check_before_reset):
                detection_with_url_metadata = dict(metadata_from_url)
                if "DATE_PREFIX_value" in temp_check_before_reset:
                    detection_with_url_metadata["date_context"] = temp_check_before_reset["DATE_PREFIX_value"]
                detection_with_url_metadata["date_value_1"] = temp_check_before_reset["DATE_value_1"]
                detection_with_url_metadata["date_separator"] = temp_check_before_reset["DATE_SEPARATOR_value"]
                detection_with_url_metadata["date_value_2"] = temp_check_before_reset["DATE_value_2"]
                forward_result.append(detection_with_url_metadata)
            # If we have a single value statment
            elif ("START_detected" in temp_check_before_reset and
                "CONSTRUCT_detected" in temp_check_before_reset and
                "DATE_value_1" in temp_check_before_reset):
                detection_with_url_metadata = dict(metadata_from_url)
                if "DATE_PREFIX_value" in temp_check_before_reset:
                    detection_with_url_metadata["date_context"] = temp_check_before_reset["DATE_PREFIX_value"]
                detection_with_url_metadata["date_value_1"] = temp_check_before_reset["DATE_value_1"]
                forward_result.append(detection_with_url_metadata)
            temp_check_before_reset.clear()

        # Conclude on current detections
        if ("START_detected" in temp_detection_dictionary and
            "CONSTRUCT_detected" in temp_detection_dictionary and
            "DATE_value_1" in temp_detection_dictionary and
            "DATE_SEPARATOR_value" in temp_detection_dictionary and
            "DATE_value_2" in temp_detection_dictionary):
            # we have a full statment.
            # add and reset.
            detection_with_url_metadata = dict(metadata_from_url)
            if "DATE_PREFIX_value" in temp_detection_dictionary:
                detection_with_url_metadata["date_context"] = temp_detection_dictionary["DATE_PREFIX_value"]
            detection_with_url_metadata["date_value_1"] = temp_detection_dictionary["DATE_value_1"]
            detection_with_url_metadata["date_separator"] = temp_detection_dictionary["DATE_SEPARATOR_value"]
            detection_with_url_metadata["date_value_2"] = temp_detection_dictionary["DATE_value_2"]
            forward_result.append(detection_with_url_metadata)
            temp_detection_dictionary.clear()

        else:
            # get next ent
            next_ent_index_number = ent_index_number + 1
            next_ent_label = ""
            if next_ent_index_number <= last_index_number_of_ents:
                next_ent = ents[next_ent_index_number]
                next_ent_label = next_ent["label"]
            # Q: Do we have enough for a new statment?
            if ("START_detected" in temp_detection_dictionary and
                "CONSTRUCT_detected" in temp_detection_dictionary and
                "DATE_value_1" in temp_detection_dictionary):
                # A: Yes, we have enough for a new statment.
                # Is the next ent relevant?
                if ("DATE_SEPARATOR_value" not in temp_detection_dictionary and
                    next_ent_label == "DATE_SEPARATOR"):
                    continue # we want the next ent
                elif ("DATE_SEPARATOR_value" in temp_detection_dictionary and
                    "DATE_value_2" not in temp_detection_dictionary):
                    continue # we know that the next value is a date
                else: # add the statment and move on
                    detection_with_url_metadata = dict(metadata_from_url)
                    if "DATE_PREFIX_value" in temp_detection_dictionary:
                        detection_with_url_metadata["date_context"] = temp_detection_dictionary["DATE_PREFIX_value"]
                    detection_with_url_metadata["date_value_1"] = temp_detection_dictionary["DATE_value_1"]
                    forward_result.append(detection_with_url_metadata)
                    temp_detection_dictionary.clear()

forward_result
# Out:
# [{'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '7',
#   'part_number': '1',
#   'date_context': 'after',
#   'date_value_1': '2 January 1988'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '7',
#   'part_number': '2',
#   'date_context': 'before',
#   'date_value_1': '2 January 1988'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '8',
#   'part_number': '1',
#   'date_context': 'after',
#   'date_value_1': '1 January 1992'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '8',
#   'part_number': '2',
# ...

# %% [markdown]
# # Create API responce

# %%
#
# Something that must be done 
# to make the notebook reload a function
# from a costum .py file.
#

# %reload_ext autoreload
# %autoreload 2

import importlib

import api_controller_identify_build_date_in_text_service_english_chapter_input

from api_controller_identify_build_date_in_text_service_english_chapter_input import create_api_response_for_post_identify_build_date_in_text_service_english_chapter_input

importlib.reload(api_controller_identify_build_date_in_text_service_english_chapter_input)

#####

create_api_response_for_post_identify_build_date_in_text_service_english_chapter_input(forward_filtered_result_with_only_the_things_we_are_looking_for)
# Out:
# [{'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '7',
#   'part_number': '1',
#   'date_context': 'after',
#   'date_value_1': '2 January 1988'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '7',
#   'part_number': '2',
#   'date_context': 'before',
#   'date_value_1': '2 January 1988'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '8',
#   'part_number': '1',
#   'date_context': 'after',
#   'date_value_1': '1 January 1992'},
#  {'regulation_year': '2013',
#   'regulation_month': '11',
#   'regulation_day': '22',
#   'regulation_id': '1404',
#   'chapter_number': '3',
#   'section_number': '8',
#   'part_number': '2',
# ...
